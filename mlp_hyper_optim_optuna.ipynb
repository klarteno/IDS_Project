# %%
# %reload_ext autoreload
# %autoreload 2

import optuna
import torch

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ##### Hyperparameter Tuning with Accuracy Pruning </br>

# %%
import models_hyper_optim_optuna
import models
import neural_net_model_train


def setFolders(evaluation_function):
    #set folders where models will be saved
    mlp_path_root_model = "models\mlp\\"+ evaluation_function
    models_hyper_optim_optuna.createFolder(mlp_path_root_model)  
    return mlp_path_root_model + "\mlp_"

# %%
channels = 1
batch_size= 32

args_model = {
    'number_of_classes':models_hyper_optim_optuna.number_of_classes, 
    'input_shape' : (32, channels, models_hyper_optim_optuna.input_size)
    }


args_trial = {
    'max_epochs' : 7,
    'no_trials': 7, 
    'evaluation_function':'accuracy', 
    'USE_AUTOMATIC_MIXED_PRECISION':False
}

#set models that will be used for tunning
mlp_model = models.MlpModel(args_model)
models_trainning = neural_net_model_train.ModelsTrainning()

# %% [markdown]
# ### Accuracy Tunning

# %%
from time import time

start = time()

args_trial['evaluation_function']='accuracy'
path_models_id = setFolders(args_trial['evaluation_function'])

study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(seed=1121218),
                            pruner=optuna.pruners.HyperbandPruner(min_resource=3))

'''study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.MedianPruner())'''

models_hyper_optim_optuna.start_optimize_objective(study, args_trial,
                                                   path_models_id,
                                                   mlp_model, 
                                                   models_trainning)
end = time()
# Out:
# [I 2022-09-28 11:51:30,658] A new study created in memory with name: no-name-9ddb9bf4-a9c2-4e2d-9f6d-2f42959f6560
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=115, bias=True)
#   (bn1): BatchNorm1d(115, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21188057241438274, inplace=False)
#   (lin2): Linear(in_features=115, out_features=151, bias=True)
#   (bn2): BatchNorm1d(151, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.20908383005814535, inplace=False)
#   (lin3): Linear(in_features=151, out_features=139, bias=True)
#   (bn3): BatchNorm1d(139, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.17490465365600258, inplace=False)
#   (lin4): Linear(in_features=139, out_features=208, bias=True)
#   (bn4): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4351588652635723, inplace=False)
#   (lin5): Linear(in_features=208, out_features=34, bias=True)
#   (bn5): BatchNorm1d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.31068252985882033, inplace=False)
#   (lin6): Linear(in_features=34, out_features=217, bias=True)
#   (bn6): BatchNorm1d(217, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.4612289778084963, inplace=False)
#   (lin7): Linear(in_features=217, out_features=58, bias=True)
#   (bn7): BatchNorm1d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.14792666261716694, inplace=False)
#   (fc_output): Linear(in_features=58, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 29.77it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.24it/s]
# 100%|██████████| 46/46 [00:00<00:00, 49.20it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.83it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.88it/s]
# 100%|██████████| 46/46 [00:01<00:00, 40.45it/s]
# 100%|██████████| 46/46 [00:01<00:00, 41.90it/s]
# Train set: Average loss: 0.0685, Average accuracy: 2.8470%,
#  	 Average f1_score: 0.0682, Average Area Under ROC: 0.5022
# 100%|██████████| 46/46 [00:00<00:00, 97.18it/s]
# [I 2022-09-28 11:51:39,601] Trial 0 finished with value: 0.06861413270235062 and parameters: {'n_layers': 7, 'n_units_l0': 115, 'dropout_l0': 0.21188057241438274, 'n_units_l1': 151, 'dropout_l1': 0.20908383005814535, 'n_units_l2': 139, 'dropout_l2': 0.17490465365600258, 'n_units_l3': 208, 'dropout_l3': 0.4351588652635723, 'n_units_l4': 34, 'dropout_l4': 0.31068252985882033, 'n_units_l5': 217, 'dropout_l5': 0.4612289778084963, 'n_units_l6': 58, 'dropout_l6': 0.14792666261716694, 'learning_rate': 0.00024636626958405986, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.06861413270235062.
# Test set: Average loss: 2.7275, Average accuracy: 0.0686%,
#  	  Average f1_score: 0.0656, Average Area Under ROC: 0.5004
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=205, bias=True)
#   (bn1): BatchNorm1d(205, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2801257911509565, inplace=False)
#   (lin2): Linear(in_features=205, out_features=79, bias=True)
#   (bn2): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4627697642078715, inplace=False)
#   (lin3): Linear(in_features=79, out_features=100, bias=True)
#   (bn3): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.44533726453576944, inplace=False)
#   (lin4): Linear(in_features=100, out_features=157, bias=True)
#   (bn4): BatchNorm1d(157, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.10241897558912853, inplace=False)
#   (fc_output): Linear(in_features=157, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 66.86it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.61it/s]
# 100%|██████████| 46/46 [00:00<00:00, 50.12it/s]
# 100%|██████████| 46/46 [00:00<00:00, 58.01it/s]
# 100%|██████████| 46/46 [00:00<00:00, 82.01it/s]
# 100%|██████████| 46/46 [00:00<00:00, 85.29it/s]
# 100%|██████████| 46/46 [00:00<00:00, 88.76it/s]
# Train set: Average loss: 0.0664, Average accuracy: 2.8800%,
#  	 Average f1_score: 0.0659, Average Area Under ROC: 0.5033
# 100%|██████████| 46/46 [00:00<00:00, 130.00it/s]
# [I 2022-09-28 11:51:45,139] Trial 1 finished with value: 0.06997282803058624 and parameters: {'n_layers': 4, 'n_units_l0': 205, 'dropout_l0': 0.2801257911509565, 'n_units_l1': 79, 'dropout_l1': 0.4627697642078715, 'n_units_l2': 100, 'dropout_l2': 0.44533726453576944, 'n_units_l3': 157, 'dropout_l3': 0.10241897558912853, 'learning_rate': 0.0007070694196281723, 'optimizer': 'SGD'}. Best is trial 1 with value: 0.06997282803058624.
# Test set: Average loss: 2.7508, Average accuracy: 0.0700%,
#  	  Average f1_score: 0.0689, Average Area Under ROC: 0.5006
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=241, bias=True)
#   (bn1): BatchNorm1d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2995674992152898, inplace=False)
#   (lin2): Linear(in_features=241, out_features=37, bias=True)
#   (bn2): BatchNorm1d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4407284472355642, inplace=False)
#   (lin3): Linear(in_features=37, out_features=148, bias=True)
#   (bn3): BatchNorm1d(148, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.10341397905208584, inplace=False)
#   (lin4): Linear(in_features=148, out_features=172, bias=True)
#   (bn4): BatchNorm1d(172, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.28250307847361844, inplace=False)
#   (lin5): Linear(in_features=172, out_features=79, bias=True)
#   (bn5): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.25178055641495606, inplace=False)
#   (lin6): Linear(in_features=79, out_features=124, bias=True)
#   (bn6): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.21221370129395184, inplace=False)
#   (lin7): Linear(in_features=124, out_features=49, bias=True)
#   (bn7): BatchNorm1d(49, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.17754711337952578, inplace=False)
#   (fc_output): Linear(in_features=49, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 53.14it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.44it/s]
# 100%|██████████| 46/46 [00:01<00:00, 44.95it/s]
# 100%|██████████| 46/46 [00:00<00:00, 54.78it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.91it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.83it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.89it/s]
# Train set: Average loss: 0.0645, Average accuracy: 2.9024%,
#  	 Average f1_score: 0.0642, Average Area Under ROC: 0.4953
# 100%|██████████| 46/46 [00:00<00:00, 103.04it/s]
# [I 2022-09-28 11:51:51,805] Trial 2 finished with value: 0.06861413270235062 and parameters: {'n_layers': 7, 'n_units_l0': 241, 'dropout_l0': 0.2995674992152898, 'n_units_l1': 37, 'dropout_l1': 0.4407284472355642, 'n_units_l2': 148, 'dropout_l2': 0.10341397905208584, 'n_units_l3': 172, 'dropout_l3': 0.28250307847361844, 'n_units_l4': 79, 'dropout_l4': 0.25178055641495606, 'n_units_l5': 124, 'dropout_l5': 0.21221370129395184, 'n_units_l6': 49, 'dropout_l6': 0.17754711337952578, 'learning_rate': 0.000964579208798786, 'optimizer': 'SGD'}. Best is trial 1 with value: 0.06997282803058624.
# Test set: Average loss: 2.7558, Average accuracy: 0.0686%,
#  	  Average f1_score: 0.0698, Average Area Under ROC: 0.5018
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=211, bias=True)
#   (bn1): BatchNorm1d(211, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.10033679641823146, inplace=False)
#   (lin2): Linear(in_features=211, out_features=253, bias=True)
#   (bn2): BatchNorm1d(253, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.24422313288473307, inplace=False)
#   (lin3): Linear(in_features=253, out_features=67, bias=True)
#   (bn3): BatchNorm1d(67, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.39538557899642424, inplace=False)
#   (lin4): Linear(in_features=67, out_features=229, bias=True)
#   (bn4): BatchNorm1d(229, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.25242206411332313, inplace=False)
#   (lin5): Linear(in_features=229, out_features=91, bias=True)
#   (bn5): BatchNorm1d(91, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.10198018650777338, inplace=False)
#   (lin6): Linear(in_features=91, out_features=124, bias=True)
#   (bn6): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.1968882851939977, inplace=False)
#   (lin7): Linear(in_features=124, out_features=184, bias=True)
#   (bn7): BatchNorm1d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.43427777669144063, inplace=False)
#   (lin8): Linear(in_features=184, out_features=250, bias=True)
#   (bn8): BatchNorm1d(250, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.3957910558367814, inplace=False)
#   (lin9): Linear(in_features=250, out_features=118, bias=True)
#   (bn9): BatchNorm1d(118, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.32610837412043636, inplace=False)
#   (fc_output): Linear(in_features=118, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 26.35it/s]
# 100%|██████████| 46/46 [00:01<00:00, 34.12it/s]
# 100%|██████████| 46/46 [00:01<00:00, 33.36it/s]
# 100%|██████████| 46/46 [00:01<00:00, 33.96it/s]
# 100%|██████████| 46/46 [00:01<00:00, 31.43it/s]
# 100%|██████████| 46/46 [00:01<00:00, 31.11it/s]
# 100%|██████████| 46/46 [00:01<00:00, 31.92it/s]
# Train set: Average loss: 0.0681, Average accuracy: 2.7581%,
#  	 Average f1_score: 0.0652, Average Area Under ROC: 0.5001
# 100%|██████████| 46/46 [00:00<00:00, 63.11it/s]
# [I 2022-09-28 11:52:03,113] Trial 3 finished with value: 0.05978260934352875 and parameters: {'n_layers': 9, 'n_units_l0': 211, 'dropout_l0': 0.10033679641823146, 'n_units_l1': 253, 'dropout_l1': 0.24422313288473307, 'n_units_l2': 67, 'dropout_l2': 0.39538557899642424, 'n_units_l3': 229, 'dropout_l3': 0.25242206411332313, 'n_units_l4': 91, 'dropout_l4': 0.10198018650777338, 'n_units_l5': 124, 'dropout_l5': 0.1968882851939977, 'n_units_l6': 184, 'dropout_l6': 0.43427777669144063, 'n_units_l7': 250, 'dropout_l7': 0.3957910558367814, 'n_units_l8': 118, 'dropout_l8': 0.32610837412043636, 'learning_rate': 0.05846124733866013, 'optimizer': 'Adam'}. Best is trial 1 with value: 0.06997282803058624.
# Test set: Average loss: 2.7309, Average accuracy: 0.0598%,
#  	  Average f1_score: 0.0574, Average Area Under ROC: 0.4855
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=232, bias=True)
#   (bn1): BatchNorm1d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2923519897124375, inplace=False)
#   (lin2): Linear(in_features=232, out_features=154, bias=True)
#   (bn2): BatchNorm1d(154, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.20203322065730517, inplace=False)
#   (lin3): Linear(in_features=154, out_features=64, bias=True)
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.1819459735105668, inplace=False)
#   (lin4): Linear(in_features=64, out_features=97, bias=True)
#   (bn4): BatchNorm1d(97, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.33687851062603175, inplace=False)
#   (lin5): Linear(in_features=97, out_features=46, bias=True)
#   (bn5): BatchNorm1d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.18190038443207113, inplace=False)
#   (lin6): Linear(in_features=46, out_features=187, bias=True)
#   (bn6): BatchNorm1d(187, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.21980962848573365, inplace=False)
#   (lin7): Linear(in_features=187, out_features=244, bias=True)
#   (bn7): BatchNorm1d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.1042631680708576, inplace=False)
#   (lin8): Linear(in_features=244, out_features=166, bias=True)
#   (bn8): BatchNorm1d(166, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.35150570999975567, inplace=False)
#   (fc_output): Linear(in_features=166, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 24.58it/s]
# 100%|██████████| 46/46 [00:01<00:00, 36.65it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.56it/s]
# 100%|██████████| 46/46 [00:01<00:00, 39.23it/s]
# [I 2022-09-28 11:52:08,811] Trial 4 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=235, bias=True)
#   (bn1): BatchNorm1d(235, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21110346016702355, inplace=False)
#   (lin2): Linear(in_features=235, out_features=118, bias=True)
#   (bn2): BatchNorm1d(118, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.12356627958564922, inplace=False)
#   (fc_output): Linear(in_features=118, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 80.71it/s]
# 100%|██████████| 46/46 [00:00<00:00, 78.48it/s]
# 100%|██████████| 46/46 [00:00<00:00, 68.50it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.76it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.42it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.65it/s]
# 100%|██████████| 46/46 [00:00<00:00, 75.47it/s]
# Train set: Average loss: 0.0672, Average accuracy: 2.7826%,
#  	 Average f1_score: 0.0670, Average Area Under ROC: 0.5026
# 100%|██████████| 46/46 [00:00<00:00, 105.60it/s]
# [I 2022-09-28 11:52:14,157] Trial 5 finished with value: 0.06657608598470688 and parameters: {'n_layers': 2, 'n_units_l0': 235, 'dropout_l0': 0.21110346016702355, 'n_units_l1': 118, 'dropout_l1': 0.12356627958564922, 'learning_rate': 0.0033592565591159074, 'optimizer': 'Adam'}. Best is trial 1 with value: 0.06997282803058624.
# Test set: Average loss: 2.7495, Average accuracy: 0.0666%,
#  	  Average f1_score: 0.0665, Average Area Under ROC: 0.4952
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=88, bias=True)
#   (bn1): BatchNorm1d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.1722212064740261, inplace=False)
#   (lin2): Linear(in_features=88, out_features=76, bias=True)
#   (bn2): BatchNorm1d(76, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.1922877445469326, inplace=False)
#   (lin3): Linear(in_features=76, out_features=37, bias=True)
#   (bn3): BatchNorm1d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.44260971264929394, inplace=False)
#   (lin4): Linear(in_features=37, out_features=208, bias=True)
#   (bn4): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.11405509684747357, inplace=False)
#   (lin5): Linear(in_features=208, out_features=211, bias=True)
#   (bn5): BatchNorm1d(211, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.10502874942969552, inplace=False)
#   (lin6): Linear(in_features=211, out_features=40, bias=True)
#   (bn6): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.13218443477752279, inplace=False)
#   (lin7): Linear(in_features=40, out_features=208, bias=True)
#   (bn7): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.2594675905494614, inplace=False)
#   (fc_output): Linear(in_features=208, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 33.64it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.12it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.91it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.77it/s]
# 100%|██████████| 46/46 [00:01<00:00, 40.94it/s]
# 100%|██████████| 46/46 [00:01<00:00, 44.39it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.32it/s]
# Train set: Average loss: 0.0662, Average accuracy: 2.8104%,
#  	 Average f1_score: 0.0659, Average Area Under ROC: 0.5012
# 100%|██████████| 46/46 [00:00<00:00, 88.67it/s]
# [I 2022-09-28 11:52:23,043] Trial 6 finished with value: 0.0625 and parameters: {'n_layers': 7, 'n_units_l0': 88, 'dropout_l0': 0.1722212064740261, 'n_units_l1': 76, 'dropout_l1': 0.1922877445469326, 'n_units_l2': 37, 'dropout_l2': 0.44260971264929394, 'n_units_l3': 208, 'dropout_l3': 0.11405509684747357, 'n_units_l4': 211, 'dropout_l4': 0.10502874942969552, 'n_units_l5': 40, 'dropout_l5': 0.13218443477752279, 'n_units_l6': 208, 'dropout_l6': 0.2594675905494614, 'learning_rate': 0.00629211233437548, 'optimizer': 'Adam'}. Best is trial 1 with value: 0.06997282803058624.
# Test set: Average loss: 2.7302, Average accuracy: 0.0625%,
#  	  Average f1_score: 0.0588, Average Area Under ROC: 0.5049

# %%
trials_finished = study.get_trials()
print('number of trials finished: ', len(trials_finished),'\n')

print('number of the best trial: ',study.best_trial.number)

best_trial = study.best_trial
for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# number of trials finished:  7
#
# number of the best trial:  1
# n_layers: 4
# n_units_l0: 205
# dropout_l0: 0.2801257911509565
# n_units_l1: 79
# dropout_l1: 0.4627697642078715
# n_units_l2: 100
# dropout_l2: 0.44533726453576944
# n_units_l3: 157
# dropout_l3: 0.10241897558912853
# learning_rate: 0.0007070694196281723
# optimizer: SGD

# %% [markdown]
# ### Tuning Visualization

# %%
import plotly
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_slice(study)

# %% [markdown]
# ### F1 score Tunning

# %%
args_trial['evaluation_function']='f1_score'
path_models_id = setFolders(args_trial['evaluation_function'])


study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(seed=1121218),
                            pruner=optuna.pruners.HyperbandPruner(min_resource=3))

models_hyper_optim_optuna.start_optimize_objective(study, args_trial,
                                                   path_models_id,
                                                   mlp_model,
                                                   models_trainning)
# Out:
# [I 2022-09-28 11:52:31,543] A new study created in memory with name: no-name-4298931c-81d9-4337-bacf-0d3a185f203c
# c:\Users\androgo\anaconda3\envs\pytorch_env\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning:
#
# Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=115, bias=True)
#   (bn1): BatchNorm1d(115, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21188057241438274, inplace=False)
#   (lin2): Linear(in_features=115, out_features=151, bias=True)
#   (bn2): BatchNorm1d(151, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.20908383005814535, inplace=False)
#   (lin3): Linear(in_features=151, out_features=139, bias=True)
#   (bn3): BatchNorm1d(139, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.17490465365600258, inplace=False)
#   (lin4): Linear(in_features=139, out_features=208, bias=True)
#   (bn4): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4351588652635723, inplace=False)
#   (lin5): Linear(in_features=208, out_features=34, bias=True)
#   (bn5): BatchNorm1d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.31068252985882033, inplace=False)
#   (lin6): Linear(in_features=34, out_features=217, bias=True)
#   (bn6): BatchNorm1d(217, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.4612289778084963, inplace=False)
#   (lin7): Linear(in_features=217, out_features=58, bias=True)
#   (bn7): BatchNorm1d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.14792666261716694, inplace=False)
#   (fc_output): Linear(in_features=58, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:02<00:00, 23.00it/s]
# 100%|██████████| 46/46 [00:02<00:00, 16.94it/s]
# 100%|██████████| 46/46 [00:02<00:00, 16.96it/s]
# 100%|██████████| 46/46 [00:02<00:00, 18.90it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.33it/s]
# 100%|██████████| 46/46 [00:01<00:00, 38.13it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.56it/s]
# Train set: Average loss: 0.0683, Average accuracy: 2.8314%,
#  	 Average f1_score: 0.0686, Average Area Under ROC: 0.5045
# 100%|██████████| 46/46 [00:00<00:00, 94.27it/s]
# [I 2022-09-28 11:52:45,965] Trial 0 finished with value: 0.06317906081676483 and parameters: {'n_layers': 7, 'n_units_l0': 115, 'dropout_l0': 0.21188057241438274, 'n_units_l1': 151, 'dropout_l1': 0.20908383005814535, 'n_units_l2': 139, 'dropout_l2': 0.17490465365600258, 'n_units_l3': 208, 'dropout_l3': 0.4351588652635723, 'n_units_l4': 34, 'dropout_l4': 0.31068252985882033, 'n_units_l5': 217, 'dropout_l5': 0.4612289778084963, 'n_units_l6': 58, 'dropout_l6': 0.14792666261716694, 'learning_rate': 0.00024636626958405986, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.06317906081676483.
# Test set: Average loss: 2.7296, Average accuracy: 0.0625%,
#  	  Average f1_score: 0.0632, Average Area Under ROC: 0.5048
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=205, bias=True)
#   (bn1): BatchNorm1d(205, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2801257911509565, inplace=False)
#   (lin2): Linear(in_features=205, out_features=79, bias=True)
#   (bn2): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4627697642078715, inplace=False)
#   (lin3): Linear(in_features=79, out_features=100, bias=True)
#   (bn3): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.44533726453576944, inplace=False)
#   (lin4): Linear(in_features=100, out_features=157, bias=True)
#   (bn4): BatchNorm1d(157, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.10241897558912853, inplace=False)
#   (fc_output): Linear(in_features=157, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 76.50it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.52it/s]
# 100%|██████████| 46/46 [00:00<00:00, 69.42it/s]
# 100%|██████████| 46/46 [00:00<00:00, 79.40it/s]
# 100%|██████████| 46/46 [00:00<00:00, 79.63it/s]
# 100%|██████████| 46/46 [00:00<00:00, 70.88it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.40it/s]
# Train set: Average loss: 0.0692, Average accuracy: 2.8688%,
#  	 Average f1_score: 0.0687, Average Area Under ROC: 0.5006
# 100%|██████████| 46/46 [00:00<00:00, 107.90it/s]
# [I 2022-09-28 11:52:51,163] Trial 1 finished with value: 0.07277019321918488 and parameters: {'n_layers': 4, 'n_units_l0': 205, 'dropout_l0': 0.2801257911509565, 'n_units_l1': 79, 'dropout_l1': 0.4627697642078715, 'n_units_l2': 100, 'dropout_l2': 0.44533726453576944, 'n_units_l3': 157, 'dropout_l3': 0.10241897558912853, 'learning_rate': 0.0007070694196281723, 'optimizer': 'SGD'}. Best is trial 1 with value: 0.07277019321918488.
# Test set: Average loss: 2.7396, Average accuracy: 0.0727%,
#  	  Average f1_score: 0.0728, Average Area Under ROC: 0.5078
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=241, bias=True)
#   (bn1): BatchNorm1d(241, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2995674992152898, inplace=False)
#   (lin2): Linear(in_features=241, out_features=37, bias=True)
#   (bn2): BatchNorm1d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4407284472355642, inplace=False)
#   (lin3): Linear(in_features=37, out_features=148, bias=True)
#   (bn3): BatchNorm1d(148, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.10341397905208584, inplace=False)
#   (lin4): Linear(in_features=148, out_features=172, bias=True)
#   (bn4): BatchNorm1d(172, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.28250307847361844, inplace=False)
#   (lin5): Linear(in_features=172, out_features=79, bias=True)
#   (bn5): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.25178055641495606, inplace=False)
#   (lin6): Linear(in_features=79, out_features=124, bias=True)
#   (bn6): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.21221370129395184, inplace=False)
#   (lin7): Linear(in_features=124, out_features=49, bias=True)
#   (bn7): BatchNorm1d(49, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.17754711337952578, inplace=False)
#   (fc_output): Linear(in_features=49, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 59.85it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.07it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.01it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.18it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.27it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.99it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.08it/s]
# Train set: Average loss: 0.0636, Average accuracy: 2.9074%,
#  	 Average f1_score: 0.0634, Average Area Under ROC: 0.4973
# 100%|██████████| 46/46 [00:00<00:00, 96.50it/s]
# [I 2022-09-28 11:52:58,273] Trial 2 finished with value: 0.07800259441137314 and parameters: {'n_layers': 7, 'n_units_l0': 241, 'dropout_l0': 0.2995674992152898, 'n_units_l1': 37, 'dropout_l1': 0.4407284472355642, 'n_units_l2': 148, 'dropout_l2': 0.10341397905208584, 'n_units_l3': 172, 'dropout_l3': 0.28250307847361844, 'n_units_l4': 79, 'dropout_l4': 0.25178055641495606, 'n_units_l5': 124, 'dropout_l5': 0.21221370129395184, 'n_units_l6': 49, 'dropout_l6': 0.17754711337952578, 'learning_rate': 0.000964579208798786, 'optimizer': 'SGD'}. Best is trial 2 with value: 0.07800259441137314.
# Test set: Average loss: 2.7522, Average accuracy: 0.0802%,
#  	  Average f1_score: 0.0780, Average Area Under ROC: 0.5025
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=211, bias=True)
#   (bn1): BatchNorm1d(211, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.10033679641823146, inplace=False)
#   (lin2): Linear(in_features=211, out_features=253, bias=True)
#   (bn2): BatchNorm1d(253, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.24422313288473307, inplace=False)
#   (lin3): Linear(in_features=253, out_features=67, bias=True)
#   (bn3): BatchNorm1d(67, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.39538557899642424, inplace=False)
#   (lin4): Linear(in_features=67, out_features=229, bias=True)
#   (bn4): BatchNorm1d(229, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.25242206411332313, inplace=False)
#   (lin5): Linear(in_features=229, out_features=91, bias=True)
#   (bn5): BatchNorm1d(91, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.10198018650777338, inplace=False)
#   (lin6): Linear(in_features=91, out_features=124, bias=True)
#   (bn6): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.1968882851939977, inplace=False)
#   (lin7): Linear(in_features=124, out_features=184, bias=True)
#   (bn7): BatchNorm1d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.43427777669144063, inplace=False)
#   (lin8): Linear(in_features=184, out_features=250, bias=True)
#   (bn8): BatchNorm1d(250, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.3957910558367814, inplace=False)
#   (lin9): Linear(in_features=250, out_features=118, bias=True)
#   (bn9): BatchNorm1d(118, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.32610837412043636, inplace=False)
#   (fc_output): Linear(in_features=118, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 28.80it/s]
# 100%|██████████| 46/46 [00:01<00:00, 29.23it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.38it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.92it/s]
# [I 2022-09-28 11:53:04,192] Trial 3 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=232, bias=True)
#   (bn1): BatchNorm1d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2923519897124375, inplace=False)
#   (lin2): Linear(in_features=232, out_features=154, bias=True)
#   (bn2): BatchNorm1d(154, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.20203322065730517, inplace=False)
#   (lin3): Linear(in_features=154, out_features=64, bias=True)
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.1819459735105668, inplace=False)
#   (lin4): Linear(in_features=64, out_features=97, bias=True)
#   (bn4): BatchNorm1d(97, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.33687851062603175, inplace=False)
#   (lin5): Linear(in_features=97, out_features=46, bias=True)
#   (bn5): BatchNorm1d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.18190038443207113, inplace=False)
#   (lin6): Linear(in_features=46, out_features=187, bias=True)
#   (bn6): BatchNorm1d(187, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.21980962848573365, inplace=False)
#   (lin7): Linear(in_features=187, out_features=244, bias=True)
#   (bn7): BatchNorm1d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.1042631680708576, inplace=False)
#   (lin8): Linear(in_features=244, out_features=166, bias=True)
#   (bn8): BatchNorm1d(166, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.35150570999975567, inplace=False)
#   (fc_output): Linear(in_features=166, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 37.65it/s]
# 100%|██████████| 46/46 [00:01<00:00, 33.05it/s]
# 100%|██████████| 46/46 [00:01<00:00, 31.89it/s]
# 100%|██████████| 46/46 [00:01<00:00, 30.36it/s]
# [I 2022-09-28 11:53:09,954] Trial 4 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=235, bias=True)
#   (bn1): BatchNorm1d(235, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21110346016702355, inplace=False)
#   (lin2): Linear(in_features=235, out_features=118, bias=True)
#   (bn2): BatchNorm1d(118, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.12356627958564922, inplace=False)
#   (fc_output): Linear(in_features=118, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 77.41it/s]
# 100%|██████████| 46/46 [00:00<00:00, 76.92it/s]
# 100%|██████████| 46/46 [00:00<00:00, 81.56it/s]
# 100%|██████████| 46/46 [00:00<00:00, 78.73it/s]
# [I 2022-09-28 11:53:12,431] Trial 5 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=23, out_features=88, bias=True)
#   (bn1): BatchNorm1d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.1722212064740261, inplace=False)
#   (lin2): Linear(in_features=88, out_features=76, bias=True)
#   (bn2): BatchNorm1d(76, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.1922877445469326, inplace=False)
#   (lin3): Linear(in_features=76, out_features=37, bias=True)
#   (bn3): BatchNorm1d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.44260971264929394, inplace=False)
#   (lin4): Linear(in_features=37, out_features=208, bias=True)
#   (bn4): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.11405509684747357, inplace=False)
#   (lin5): Linear(in_features=208, out_features=211, bias=True)
#   (bn5): BatchNorm1d(211, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.10502874942969552, inplace=False)
#   (lin6): Linear(in_features=211, out_features=40, bias=True)
#   (bn6): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.13218443477752279, inplace=False)
#   (lin7): Linear(in_features=40, out_features=208, bias=True)
#   (bn7): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.2594675905494614, inplace=False)
#   (fc_output): Linear(in_features=208, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 45.43it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.62it/s]
# 100%|██████████| 46/46 [00:01<00:00, 42.28it/s]
# 100%|██████████| 46/46 [00:01<00:00, 42.05it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.17it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.64it/s]
# 100%|██████████| 46/46 [00:01<00:00, 36.24it/s]
# Train set: Average loss: 0.0668, Average accuracy: 2.8139%,
#  	 Average f1_score: 0.0665, Average Area Under ROC: 0.4996
# 100%|██████████| 46/46 [00:00<00:00, 82.65it/s]
# [I 2022-09-28 11:53:21,117] Trial 6 finished with value: 0.07237526774406433 and parameters: {'n_layers': 7, 'n_units_l0': 88, 'dropout_l0': 0.1722212064740261, 'n_units_l1': 76, 'dropout_l1': 0.1922877445469326, 'n_units_l2': 37, 'dropout_l2': 0.44260971264929394, 'n_units_l3': 208, 'dropout_l3': 0.11405509684747357, 'n_units_l4': 211, 'dropout_l4': 0.10502874942969552, 'n_units_l5': 40, 'dropout_l5': 0.13218443477752279, 'n_units_l6': 208, 'dropout_l6': 0.2594675905494614, 'learning_rate': 0.00629211233437548, 'optimizer': 'Adam'}. Best is trial 2 with value: 0.07800259441137314.
# Test set: Average loss: 2.7250, Average accuracy: 0.0747%,
#  	  Average f1_score: 0.0724, Average Area Under ROC: 0.5034

# %%
trials_finished = study.get_trials()
print('number of trials finished: ', len(trials_finished),'\n')

print('number of the best trial: ',study.best_trial.number)

for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# number of trials finished:  7
#
# number of the best trial:  2
# n_layers: 4
# n_units_l0: 205
# dropout_l0: 0.2801257911509565
# n_units_l1: 79
# dropout_l1: 0.4627697642078715
# n_units_l2: 100
# dropout_l2: 0.44533726453576944
# n_units_l3: 157
# dropout_l3: 0.10241897558912853
# learning_rate: 0.0007070694196281723
# optimizer: SGD

# %% [markdown]
# ### Tuning Visualization

# %%
import plotly
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_slice(study)
