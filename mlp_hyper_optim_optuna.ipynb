# %%
# %reload_ext autoreload
# %autoreload 2

import optuna
import torch
# Out:
# DEVICE found:  cuda:0
# number of classes:  15
# DEVICE found:  cuda:0
# number of classes:  15

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ##### Hyperparameter Tuning with Accuracy Pruning </br>

# %%
import models_hyper_optim_optuna
import models
import neural_net_model_train

# %%
channels = 1
batch_size= 32

args_model = {
    'number_of_classes':models_hyper_optim_optuna.number_of_classes, 
    'input_shape' : (32, channels, models_hyper_optim_optuna.input_size)
    }


args_trial = {
    'max_epochs' : 7,
    'no_trials': 17, 
    'evaluation_function':'accuracy', 
    'USE_AUTOMATIC_MIXED_PRECISION':True
}

mlp_model = models.MlpModel(args_model)
models_trainning = neural_net_model_train.ModelsTrainning()

# %% [markdown]
# ### Accuracy Tunning

# %%
from time import time

start = time()

args_trial['evaluation_function']='accuracy'


study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.HyperbandPruner(min_resource=3))

'''study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.MedianPruner())'''

models_hyper_optim_optuna.start_optimize_objective(study, args_trial,
                                                   mlp_model, models_trainning)
end = time()
# Out:
# [I 2022-09-27 10:31:52,401] A new study created in memory with name: no-name-913ca2b5-2db6-4835-b5ae-092546137fec
# c:\Users\androgo\anaconda3\envs\pytorch_env\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning:
#
# Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=52, bias=True)
#   (bn1): BatchNorm1d(52, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2032542323864882, inplace=False)
#   (lin2): Linear(in_features=52, out_features=216, bias=True)
#   (bn2): BatchNorm1d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.18178819689589512, inplace=False)
#   (lin3): Linear(in_features=216, out_features=56, bias=True)
#   (bn3): BatchNorm1d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.2818073418605701, inplace=False)
#   (lin4): Linear(in_features=56, out_features=195, bias=True)
#   (bn4): BatchNorm1d(195, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.16175627849027951, inplace=False)
#   (lin5): Linear(in_features=195, out_features=249, bias=True)
#   (bn5): BatchNorm1d(249, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.41725703915055523, inplace=False)
#   (fc_output): Linear(in_features=249, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 66.56it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.03it/s]
# 100%|██████████| 46/46 [00:00<00:00, 69.98it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.15it/s]
# 100%|██████████| 46/46 [00:00<00:00, 63.67it/s]
# 100%|██████████| 46/46 [00:00<00:00, 66.98it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.04it/s]
# Train set: Average loss: 0.0645, Average accuracy: 2.8963%,
#  	 Average f1_score: 0.0648, Average Area Under ROC: 0.4999
# 100%|██████████| 46/46 [00:00<00:00, 127.87it/s]
# [I 2022-09-27 10:31:57,708] Trial 0 finished with value: 0.07201086729764938 and parameters: {'n_layers': 5, 'n_units_l0': 52, 'dropout_l0': 0.2032542323864882, 'n_units_l1': 216, 'dropout_l1': 0.18178819689589512, 'n_units_l2': 56, 'dropout_l2': 0.2818073418605701, 'n_units_l3': 195, 'dropout_l3': 0.16175627849027951, 'n_units_l4': 249, 'dropout_l4': 0.41725703915055523, 'learning_rate': 0.045651625308758555, 'optimizer': 'SGD'}. Best is trial 0 with value: 0.07201086729764938.
# Test set: Average loss: 2.7574, Average accuracy: 0.0720%,
#  	  Average f1_score: 0.0718, Average Area Under ROC: 0.4961
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=163, bias=True)
#   (bn1): BatchNorm1d(163, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.15285985791299242, inplace=False)
#   (lin2): Linear(in_features=163, out_features=163, bias=True)
#   (bn2): BatchNorm1d(163, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.29854427297489716, inplace=False)
#   (lin3): Linear(in_features=163, out_features=79, bias=True)
#   (bn3): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.22321866608285004, inplace=False)
#   (lin4): Linear(in_features=79, out_features=85, bias=True)
#   (bn4): BatchNorm1d(85, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.26221589175750337, inplace=False)
#   (lin5): Linear(in_features=85, out_features=164, bias=True)
#   (bn5): BatchNorm1d(164, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.10249569239508856, inplace=False)
#   (lin6): Linear(in_features=164, out_features=69, bias=True)
#   (bn6): BatchNorm1d(69, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.40017177120344616, inplace=False)
#   (fc_output): Linear(in_features=69, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 47.44it/s]
# 100%|██████████| 46/46 [00:00<00:00, 49.47it/s]
# 100%|██████████| 46/46 [00:00<00:00, 47.09it/s]
# 100%|██████████| 46/46 [00:01<00:00, 44.89it/s]
# 100%|██████████| 46/46 [00:00<00:00, 47.32it/s]
# 100%|██████████| 46/46 [00:00<00:00, 51.19it/s]
# 100%|██████████| 46/46 [00:00<00:00, 49.44it/s]
# Train set: Average loss: 0.0661, Average accuracy: 2.7448%,
#  	 Average f1_score: 0.0617, Average Area Under ROC: 0.4973
# 100%|██████████| 46/46 [00:00<00:00, 120.05it/s]
# [I 2022-09-27 10:32:05,067] Trial 1 finished with value: 0.06997282803058624 and parameters: {'n_layers': 6, 'n_units_l0': 163, 'dropout_l0': 0.15285985791299242, 'n_units_l1': 163, 'dropout_l1': 0.29854427297489716, 'n_units_l2': 79, 'dropout_l2': 0.22321866608285004, 'n_units_l3': 85, 'dropout_l3': 0.26221589175750337, 'n_units_l4': 164, 'dropout_l4': 0.10249569239508856, 'n_units_l5': 69, 'dropout_l5': 0.40017177120344616, 'learning_rate': 0.07046071859384058, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.07201086729764938.
# Test set: Average loss: 2.7216, Average accuracy: 0.0700%,
#  	  Average f1_score: 0.0609, Average Area Under ROC: 0.4952
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=76, bias=True)
#   (bn1): BatchNorm1d(76, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.18163156531066355, inplace=False)
#   (lin2): Linear(in_features=76, out_features=32, bias=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.3751036781731111, inplace=False)
#   (lin3): Linear(in_features=32, out_features=224, bias=True)
#   (bn3): BatchNorm1d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.30939109558271527, inplace=False)
#   (fc_output): Linear(in_features=224, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 68.26it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.29it/s]
# 100%|██████████| 46/46 [00:00<00:00, 66.49it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.82it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.91it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.37it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.31it/s]
# Train set: Average loss: 0.0636, Average accuracy: 2.7886%,
#  	 Average f1_score: 0.0596, Average Area Under ROC: 0.4984
# 100%|██████████| 46/46 [00:00<00:00, 133.71it/s]
# [I 2022-09-27 10:32:10,333] Trial 2 finished with value: 0.06046195700764656 and parameters: {'n_layers': 3, 'n_units_l0': 76, 'dropout_l0': 0.18163156531066355, 'n_units_l1': 32, 'dropout_l1': 0.3751036781731111, 'n_units_l2': 224, 'dropout_l2': 0.30939109558271527, 'learning_rate': 0.08561274339979223, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.07201086729764938.
# Test set: Average loss: 2.7254, Average accuracy: 0.0605%,
#  	  Average f1_score: 0.0567, Average Area Under ROC: 0.4960
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=121, bias=True)
#   (bn1): BatchNorm1d(121, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3215081390817982, inplace=False)
#   (lin2): Linear(in_features=121, out_features=93, bias=True)
#   (bn2): BatchNorm1d(93, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4934060138076166, inplace=False)
#   (lin3): Linear(in_features=93, out_features=234, bias=True)
#   (bn3): BatchNorm1d(234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.13775451780307668, inplace=False)
#   (fc_output): Linear(in_features=234, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 83.74it/s]
# 100%|██████████| 46/46 [00:00<00:00, 75.77it/s]
# 100%|██████████| 46/46 [00:00<00:00, 75.59it/s]
# 100%|██████████| 46/46 [00:00<00:00, 85.99it/s]
# [I 2022-09-27 10:32:12,763] Trial 3 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=100, bias=True)
#   (bn1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4344283156421511, inplace=False)
#   (lin2): Linear(in_features=100, out_features=131, bias=True)
#   (bn2): BatchNorm1d(131, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.37650821947487334, inplace=False)
#   (lin3): Linear(in_features=131, out_features=33, bias=True)
#   (bn3): BatchNorm1d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3551702867092009, inplace=False)
#   (lin4): Linear(in_features=33, out_features=212, bias=True)
#   (bn4): BatchNorm1d(212, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.23970343419141213, inplace=False)
#   (lin5): Linear(in_features=212, out_features=64, bias=True)
#   (bn5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3494871138914063, inplace=False)
#   (fc_output): Linear(in_features=64, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 72.32it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.43it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.15it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.52it/s]
# [I 2022-09-27 10:32:15,444] Trial 4 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=91, bias=True)
#   (bn1): BatchNorm1d(91, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21947566051798378, inplace=False)
#   (lin2): Linear(in_features=91, out_features=160, bias=True)
#   (bn2): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.25849563300416734, inplace=False)
#   (lin3): Linear(in_features=160, out_features=219, bias=True)
#   (bn3): BatchNorm1d(219, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3801576316634465, inplace=False)
#   (lin4): Linear(in_features=219, out_features=73, bias=True)
#   (bn4): BatchNorm1d(73, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4298740234083419, inplace=False)
#   (lin5): Linear(in_features=73, out_features=115, bias=True)
#   (bn5): BatchNorm1d(115, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.1756512199884945, inplace=False)
#   (lin6): Linear(in_features=115, out_features=179, bias=True)
#   (bn6): BatchNorm1d(179, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.4574836918719103, inplace=False)
#   (lin7): Linear(in_features=179, out_features=54, bias=True)
#   (bn7): BatchNorm1d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.4639320792545142, inplace=False)
#   (lin8): Linear(in_features=54, out_features=244, bias=True)
#   (bn8): BatchNorm1d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.4064775433315232, inplace=False)
#   (lin9): Linear(in_features=244, out_features=83, bias=True)
#   (bn9): BatchNorm1d(83, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.46910405856176807, inplace=False)
#   (fc_output): Linear(in_features=83, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 54.96it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.40it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.16it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.03it/s]
# [I 2022-09-27 10:32:18,912] Trial 5 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=46, bias=True)
#   (bn1): BatchNorm1d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3712514709140591, inplace=False)
#   (lin2): Linear(in_features=46, out_features=174, bias=True)
#   (bn2): BatchNorm1d(174, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.11731243939396459, inplace=False)
#   (lin3): Linear(in_features=174, out_features=53, bias=True)
#   (bn3): BatchNorm1d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.46964373285822025, inplace=False)
#   (lin4): Linear(in_features=53, out_features=229, bias=True)
#   (bn4): BatchNorm1d(229, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.42611476128561465, inplace=False)
#   (fc_output): Linear(in_features=229, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 72.15it/s]
# 100%|██████████| 46/46 [00:00<00:00, 73.19it/s]
# 100%|██████████| 46/46 [00:00<00:00, 70.69it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.11it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.64it/s]
# 100%|██████████| 46/46 [00:00<00:00, 73.55it/s]
# 100%|██████████| 46/46 [00:00<00:00, 72.83it/s]
# Train set: Average loss: 0.0661, Average accuracy: 2.9292%,
#  	 Average f1_score: 0.0638, Average Area Under ROC: 0.5040
# 100%|██████████| 46/46 [00:00<00:00, 137.37it/s]
# [I 2022-09-27 10:32:23,935] Trial 6 finished with value: 0.06589674204587936 and parameters: {'n_layers': 4, 'n_units_l0': 46, 'dropout_l0': 0.3712514709140591, 'n_units_l1': 174, 'dropout_l1': 0.11731243939396459, 'n_units_l2': 53, 'dropout_l2': 0.46964373285822025, 'n_units_l3': 229, 'dropout_l3': 0.42611476128561465, 'learning_rate': 0.03685800289820252, 'optimizer': 'RMSprop'}. Best is trial 0 with value: 0.07201086729764938.
# Test set: Average loss: 2.7232, Average accuracy: 0.0659%,
#  	  Average f1_score: 0.0570, Average Area Under ROC: 0.5036
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=88, bias=True)
#   (bn1): BatchNorm1d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.17918867415682085, inplace=False)
#   (lin2): Linear(in_features=88, out_features=54, bias=True)
#   (bn2): BatchNorm1d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.48772160214841986, inplace=False)
#   (lin3): Linear(in_features=54, out_features=173, bias=True)
#   (bn3): BatchNorm1d(173, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.44251967454328267, inplace=False)
#   (lin4): Linear(in_features=173, out_features=187, bias=True)
#   (bn4): BatchNorm1d(187, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.1379392606031425, inplace=False)
#   (lin5): Linear(in_features=187, out_features=147, bias=True)
#   (bn5): BatchNorm1d(147, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.4906211060094714, inplace=False)
#   (fc_output): Linear(in_features=147, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 52.85it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.79it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.46it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.86it/s]
# [I 2022-09-27 10:32:27,568] Trial 7 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=82, bias=True)
#   (bn1): BatchNorm1d(82, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.18625925766142404, inplace=False)
#   (lin2): Linear(in_features=82, out_features=210, bias=True)
#   (bn2): BatchNorm1d(210, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4937269736848279, inplace=False)
#   (lin3): Linear(in_features=210, out_features=183, bias=True)
#   (bn3): BatchNorm1d(183, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.22678703281899898, inplace=False)
#   (lin4): Linear(in_features=183, out_features=150, bias=True)
#   (bn4): BatchNorm1d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4883895278628855, inplace=False)
#   (lin5): Linear(in_features=150, out_features=247, bias=True)
#   (bn5): BatchNorm1d(247, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.449465799906814, inplace=False)
#   (lin6): Linear(in_features=247, out_features=90, bias=True)
#   (bn6): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.3844676787970761, inplace=False)
#   (lin7): Linear(in_features=90, out_features=242, bias=True)
#   (bn7): BatchNorm1d(242, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.10482991978062556, inplace=False)
#   (lin8): Linear(in_features=242, out_features=219, bias=True)
#   (bn8): BatchNorm1d(219, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.41124886349658474, inplace=False)
#   (fc_output): Linear(in_features=219, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 42.20it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.52it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.82it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.47it/s]
# 100%|██████████| 46/46 [00:01<00:00, 42.31it/s]
# 100%|██████████| 46/46 [00:01<00:00, 44.12it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.39it/s]
# Train set: Average loss: 0.0674, Average accuracy: 2.8044%,
#  	 Average f1_score: 0.0634, Average Area Under ROC: 0.5010
# 100%|██████████| 46/46 [00:00<00:00, 113.35it/s]
# [I 2022-09-27 10:32:35,697] Trial 8 finished with value: 0.06929347664117813 and parameters: {'n_layers': 8, 'n_units_l0': 82, 'dropout_l0': 0.18625925766142404, 'n_units_l1': 210, 'dropout_l1': 0.4937269736848279, 'n_units_l2': 183, 'dropout_l2': 0.22678703281899898, 'n_units_l3': 150, 'dropout_l3': 0.4883895278628855, 'n_units_l4': 247, 'dropout_l4': 0.449465799906814, 'n_units_l5': 90, 'dropout_l5': 0.3844676787970761, 'n_units_l6': 242, 'dropout_l6': 0.10482991978062556, 'n_units_l7': 219, 'dropout_l7': 0.41124886349658474, 'learning_rate': 0.060233516378092836, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.07201086729764938.
# Test set: Average loss: 2.7200, Average accuracy: 0.0693%,
#  	  Average f1_score: 0.0625, Average Area Under ROC: 0.4959
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=173, bias=True)
#   (bn1): BatchNorm1d(173, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.306334279888295, inplace=False)
#   (lin2): Linear(in_features=173, out_features=143, bias=True)
#   (bn2): BatchNorm1d(143, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.2017572529884073, inplace=False)
#   (lin3): Linear(in_features=143, out_features=135, bias=True)
#   (bn3): BatchNorm1d(135, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.4039152905898068, inplace=False)
#   (lin4): Linear(in_features=135, out_features=198, bias=True)
#   (bn4): BatchNorm1d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.20621467362562199, inplace=False)
#   (fc_output): Linear(in_features=198, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 68.90it/s]
# 100%|██████████| 46/46 [00:00<00:00, 54.44it/s]
# 100%|██████████| 46/46 [00:00<00:00, 69.46it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.28it/s]
# [I 2022-09-27 10:32:38,641] Trial 9 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=237, bias=True)
#   (bn1): BatchNorm1d(237, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4873166291124967, inplace=False)
#   (lin2): Linear(in_features=237, out_features=249, bias=True)
#   (bn2): BatchNorm1d(249, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.1353662459751821, inplace=False)
#   (lin3): Linear(in_features=249, out_features=89, bias=True)
#   (bn3): BatchNorm1d(89, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.23364429629448566, inplace=False)
#   (lin4): Linear(in_features=89, out_features=26, bias=True)
#   (bn4): BatchNorm1d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.1015215845364244, inplace=False)
#   (lin5): Linear(in_features=26, out_features=255, bias=True)
#   (bn5): BatchNorm1d(255, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3328424939823516, inplace=False)
#   (lin6): Linear(in_features=255, out_features=231, bias=True)
#   (bn6): BatchNorm1d(231, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.13097556405103974, inplace=False)
#   (lin7): Linear(in_features=231, out_features=182, bias=True)
#   (bn7): BatchNorm1d(182, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.22358444942948233, inplace=False)
#   (fc_output): Linear(in_features=182, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 63.41it/s]
# 100%|██████████| 46/46 [00:00<00:00, 61.27it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.76it/s]
# 100%|██████████| 46/46 [00:00<00:00, 64.34it/s]
# 100%|██████████| 46/46 [00:00<00:00, 67.59it/s]
# 100%|██████████| 46/46 [00:00<00:00, 66.00it/s]
# 100%|██████████| 46/46 [00:00<00:00, 64.11it/s]
# Train set: Average loss: 0.0729, Average accuracy: 2.8527%,
#  	 Average f1_score: 0.0726, Average Area Under ROC: 0.5021
# 100%|██████████| 46/46 [00:00<00:00, 116.16it/s]
# [I 2022-09-27 10:32:44,351] Trial 10 finished with value: 0.07404891401529312 and parameters: {'n_layers': 7, 'n_units_l0': 237, 'dropout_l0': 0.4873166291124967, 'n_units_l1': 249, 'dropout_l1': 0.1353662459751821, 'n_units_l2': 89, 'dropout_l2': 0.23364429629448566, 'n_units_l3': 26, 'dropout_l3': 0.1015215845364244, 'n_units_l4': 255, 'dropout_l4': 0.3328424939823516, 'n_units_l5': 231, 'dropout_l5': 0.13097556405103974, 'n_units_l6': 182, 'dropout_l6': 0.22358444942948233, 'learning_rate': 0.0333735696692182, 'optimizer': 'SGD'}. Best is trial 10 with value: 0.07404891401529312.
# Test set: Average loss: 2.7342, Average accuracy: 0.0740%,
#  	  Average f1_score: 0.0726, Average Area Under ROC: 0.5054
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=251, bias=True)
#   (bn1): BatchNorm1d(251, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.49882043456231007, inplace=False)
#   (lin2): Linear(in_features=251, out_features=249, bias=True)
#   (bn2): BatchNorm1d(249, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.10407624002945245, inplace=False)
#   (lin3): Linear(in_features=249, out_features=99, bias=True)
#   (bn3): BatchNorm1d(99, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.23350774154462495, inplace=False)
#   (lin4): Linear(in_features=99, out_features=32, bias=True)
#   (bn4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.10328731144737077, inplace=False)
#   (lin5): Linear(in_features=32, out_features=257, bias=True)
#   (bn5): BatchNorm1d(257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3344817564960951, inplace=False)
#   (lin6): Linear(in_features=257, out_features=250, bias=True)
#   (bn6): BatchNorm1d(250, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.1256770818253716, inplace=False)
#   (lin7): Linear(in_features=250, out_features=183, bias=True)
#   (bn7): BatchNorm1d(183, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.21612640829058533, inplace=False)
#   (fc_output): Linear(in_features=183, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 57.59it/s]
# 100%|██████████| 46/46 [00:00<00:00, 52.34it/s]
# 100%|██████████| 46/46 [00:00<00:00, 63.81it/s]
# 100%|██████████| 46/46 [00:00<00:00, 63.42it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.26it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.83it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.29it/s]
# Train set: Average loss: 0.0699, Average accuracy: 2.8410%,
#  	 Average f1_score: 0.0701, Average Area Under ROC: 0.5010
# 100%|██████████| 46/46 [00:00<00:00, 114.58it/s]
# [I 2022-09-27 10:32:50,336] Trial 11 finished with value: 0.07404891401529312 and parameters: {'n_layers': 7, 'n_units_l0': 251, 'dropout_l0': 0.49882043456231007, 'n_units_l1': 249, 'dropout_l1': 0.10407624002945245, 'n_units_l2': 99, 'dropout_l2': 0.23350774154462495, 'n_units_l3': 32, 'dropout_l3': 0.10328731144737077, 'n_units_l4': 257, 'dropout_l4': 0.3344817564960951, 'n_units_l5': 250, 'dropout_l5': 0.1256770818253716, 'n_units_l6': 183, 'dropout_l6': 0.21612640829058533, 'learning_rate': 0.031930072746591744, 'optimizer': 'SGD'}. Best is trial 10 with value: 0.07404891401529312.
# Test set: Average loss: 2.7459, Average accuracy: 0.0740%,
#  	  Average f1_score: 0.0735, Average Area Under ROC: 0.5094
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=245, bias=True)
#   (bn1): BatchNorm1d(245, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.49766222318089554, inplace=False)
#   (lin2): Linear(in_features=245, out_features=254, bias=True)
#   (bn2): BatchNorm1d(254, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.1030560602666509, inplace=False)
#   (lin3): Linear(in_features=254, out_features=102, bias=True)
#   (bn3): BatchNorm1d(102, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.12535274641093394, inplace=False)
#   (lin4): Linear(in_features=102, out_features=27, bias=True)
#   (bn4): BatchNorm1d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.11600457957535773, inplace=False)
#   (lin5): Linear(in_features=27, out_features=200, bias=True)
#   (bn5): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.2801168694186814, inplace=False)
#   (lin6): Linear(in_features=200, out_features=257, bias=True)
#   (bn6): BatchNorm1d(257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.11235509582160537, inplace=False)
#   (lin7): Linear(in_features=257, out_features=182, bias=True)
#   (bn7): BatchNorm1d(182, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.19630496483652948, inplace=False)
#   (fc_output): Linear(in_features=182, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 54.77it/s]
# 100%|██████████| 46/46 [00:00<00:00, 52.72it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.43it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.40it/s]
# [I 2022-09-27 10:32:53,693] Trial 12 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=257, bias=True)
#   (bn1): BatchNorm1d(257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4800168954763019, inplace=False)
#   (lin2): Linear(in_features=257, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.17121937415742372, inplace=False)
#   (lin3): Linear(in_features=256, out_features=114, bias=True)
#   (bn3): BatchNorm1d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.20638159545300092, inplace=False)
#   (lin4): Linear(in_features=114, out_features=27, bias=True)
#   (bn4): BatchNorm1d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.3250541097128874, inplace=False)
#   (lin5): Linear(in_features=27, out_features=257, bias=True)
#   (bn5): BatchNorm1d(257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3010532557794311, inplace=False)
#   (lin6): Linear(in_features=257, out_features=242, bias=True)
#   (bn6): BatchNorm1d(242, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.12591518393722975, inplace=False)
#   (lin7): Linear(in_features=242, out_features=160, bias=True)
#   (bn7): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.270646556504737, inplace=False)
#   (fc_output): Linear(in_features=160, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 63.03it/s]
# 100%|██████████| 46/46 [00:00<00:00, 64.75it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.74it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.01it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.70it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.08it/s]
# 100%|██████████| 46/46 [00:00<00:00, 66.23it/s]
# Train set: Average loss: 0.0704, Average accuracy: 2.8730%,
#  	 Average f1_score: 0.0701, Average Area Under ROC: 0.5014
# 100%|██████████| 46/46 [00:00<00:00, 118.24it/s]
# [I 2022-09-27 10:32:59,333] Trial 13 finished with value: 0.06385869532823563 and parameters: {'n_layers': 7, 'n_units_l0': 257, 'dropout_l0': 0.4800168954763019, 'n_units_l1': 256, 'dropout_l1': 0.17121937415742372, 'n_units_l2': 114, 'dropout_l2': 0.20638159545300092, 'n_units_l3': 27, 'dropout_l3': 0.3250541097128874, 'n_units_l4': 257, 'dropout_l4': 0.3010532557794311, 'n_units_l5': 242, 'dropout_l5': 0.12591518393722975, 'n_units_l6': 160, 'dropout_l6': 0.270646556504737, 'learning_rate': 0.024802131189476936, 'optimizer': 'SGD'}. Best is trial 10 with value: 0.07404891401529312.
# Test set: Average loss: 2.7417, Average accuracy: 0.0639%,
#  	  Average f1_score: 0.0629, Average Area Under ROC: 0.4988
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=213, bias=True)
#   (bn1): BatchNorm1d(213, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4159200183474117, inplace=False)
#   (lin2): Linear(in_features=213, out_features=214, bias=True)
#   (bn2): BatchNorm1d(214, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.14940658895890227, inplace=False)
#   (lin3): Linear(in_features=214, out_features=93, bias=True)
#   (bn3): BatchNorm1d(93, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.179749826015962, inplace=False)
#   (lin4): Linear(in_features=93, out_features=74, bias=True)
#   (bn4): BatchNorm1d(74, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.10895248193874213, inplace=False)
#   (lin5): Linear(in_features=74, out_features=201, bias=True)
#   (bn5): BatchNorm1d(201, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3539172337397733, inplace=False)
#   (lin6): Linear(in_features=201, out_features=191, bias=True)
#   (bn6): BatchNorm1d(191, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.2216389638948057, inplace=False)
#   (lin7): Linear(in_features=191, out_features=205, bias=True)
#   (bn7): BatchNorm1d(205, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.2392056820860377, inplace=False)
#   (lin8): Linear(in_features=205, out_features=29, bias=True)
#   (bn8): BatchNorm1d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.1428068942758901, inplace=False)
#   (lin9): Linear(in_features=29, out_features=256, bias=True)
#   (bn9): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.10014102598500912, inplace=False)
#   (fc_output): Linear(in_features=256, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 44.55it/s]
# 100%|██████████| 46/46 [00:00<00:00, 46.14it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.11it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.13it/s]
# [I 2022-09-27 10:33:03,243] Trial 14 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=213, bias=True)
#   (bn1): BatchNorm1d(213, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4322572322592915, inplace=False)
#   (lin2): Linear(in_features=213, out_features=230, bias=True)
#   (bn2): BatchNorm1d(230, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.2335423074304065, inplace=False)
#   (lin3): Linear(in_features=230, out_features=142, bias=True)
#   (bn3): BatchNorm1d(142, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.28545216277963736, inplace=False)
#   (lin4): Linear(in_features=142, out_features=116, bias=True)
#   (bn4): BatchNorm1d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.18728845125688878, inplace=False)
#   (lin5): Linear(in_features=116, out_features=205, bias=True)
#   (bn5): BatchNorm1d(205, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.25592042764813505, inplace=False)
#   (lin6): Linear(in_features=205, out_features=205, bias=True)
#   (bn6): BatchNorm1d(205, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.22817388310575698, inplace=False)
#   (lin7): Linear(in_features=205, out_features=110, bias=True)
#   (bn7): BatchNorm1d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.39073913098458823, inplace=False)
#   (fc_output): Linear(in_features=110, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 60.09it/s]
# 100%|██████████| 46/46 [00:00<00:00, 50.30it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.70it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.31it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.53it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.34it/s]
# 100%|██████████| 46/46 [00:00<00:00, 58.51it/s]
# Train set: Average loss: 0.0673, Average accuracy: 2.9036%,
#  	 Average f1_score: 0.0671, Average Area Under ROC: 0.5020
# 100%|██████████| 46/46 [00:00<00:00, 110.71it/s]
# [I 2022-09-27 10:33:09,641] Trial 15 finished with value: 0.07065217196941376 and parameters: {'n_layers': 7, 'n_units_l0': 213, 'dropout_l0': 0.4322572322592915, 'n_units_l1': 230, 'dropout_l1': 0.2335423074304065, 'n_units_l2': 142, 'dropout_l2': 0.28545216277963736, 'n_units_l3': 116, 'dropout_l3': 0.18728845125688878, 'n_units_l4': 205, 'dropout_l4': 0.25592042764813505, 'n_units_l5': 205, 'dropout_l5': 0.22817388310575698, 'n_units_l6': 110, 'dropout_l6': 0.39073913098458823, 'learning_rate': 0.023862911329788947, 'optimizer': 'SGD'}. Best is trial 10 with value: 0.07404891401529312.
# Test set: Average loss: 2.7299, Average accuracy: 0.0707%,
#  	  Average f1_score: 0.0702, Average Area Under ROC: 0.5025
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=218, bias=True)
#   (bn1): BatchNorm1d(218, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.10237671122585273, inplace=False)
#   (lin2): Linear(in_features=218, out_features=191, bias=True)
#   (bn2): BatchNorm1d(191, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.12803180928467736, inplace=False)
#   (lin3): Linear(in_features=191, out_features=137, bias=True)
#   (bn3): BatchNorm1d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.25211191103335934, inplace=False)
#   (lin4): Linear(in_features=137, out_features=50, bias=True)
#   (bn4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.3074405743814155, inplace=False)
#   (lin5): Linear(in_features=50, out_features=29, bias=True)
#   (bn5): BatchNorm1d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.373137720857832, inplace=False)
#   (lin6): Linear(in_features=29, out_features=139, bias=True)
#   (bn6): BatchNorm1d(139, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.2038790232588806, inplace=False)
#   (lin7): Linear(in_features=139, out_features=121, bias=True)
#   (bn7): BatchNorm1d(121, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.15052719875183965, inplace=False)
#   (lin8): Linear(in_features=121, out_features=65, bias=True)
#   (bn8): BatchNorm1d(65, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.10086492104518438, inplace=False)
#   (fc_output): Linear(in_features=65, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 40.40it/s]
# 100%|██████████| 46/46 [00:01<00:00, 40.68it/s]
# 100%|██████████| 46/46 [00:01<00:00, 44.44it/s]
# 100%|██████████| 46/46 [00:00<00:00, 46.92it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.27it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.66it/s]
# 100%|██████████| 46/46 [00:00<00:00, 46.96it/s]
# Train set: Average loss: 0.0706, Average accuracy: 2.7549%,
#  	 Average f1_score: 0.0666, Average Area Under ROC: 0.5030
# 100%|██████████| 46/46 [00:00<00:00, 99.95it/s]
# [I 2022-09-27 10:33:17,679] Trial 16 finished with value: 0.057065218687057495 and parameters: {'n_layers': 8, 'n_units_l0': 218, 'dropout_l0': 0.10237671122585273, 'n_units_l1': 191, 'dropout_l1': 0.12803180928467736, 'n_units_l2': 137, 'dropout_l2': 0.25211191103335934, 'n_units_l3': 50, 'dropout_l3': 0.3074405743814155, 'n_units_l4': 29, 'dropout_l4': 0.373137720857832, 'n_units_l5': 139, 'dropout_l5': 0.2038790232588806, 'n_units_l6': 121, 'dropout_l6': 0.15052719875183965, 'n_units_l7': 65, 'dropout_l7': 0.10086492104518438, 'learning_rate': 0.039362802215783414, 'optimizer': 'RMSprop'}. Best is trial 10 with value: 0.07404891401529312.
# Test set: Average loss: 2.7557, Average accuracy: 0.0571%,
#  	  Average f1_score: 0.0499, Average Area Under ROC: 0.4939

# %%
trials_finished = study.get_trials()
print('number of trials finished: ', len(trials_finished),'\n')

print('number of the best trial: ',study.best_trial.number)

best_trial = study.best_trial
for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# number of trials finished:  17
#
# number of the best trial:  10
# n_layers: 7
# n_units_l0: 237
# dropout_l0: 0.4873166291124967
# n_units_l1: 249
# dropout_l1: 0.1353662459751821
# n_units_l2: 89
# dropout_l2: 0.23364429629448566
# n_units_l3: 26
# dropout_l3: 0.1015215845364244
# n_units_l4: 255
# dropout_l4: 0.3328424939823516
# n_units_l5: 231
# dropout_l5: 0.13097556405103974
# n_units_l6: 182
# dropout_l6: 0.22358444942948233
# learning_rate: 0.0333735696692182
# optimizer: SGD

# %% [markdown]
# ### Tuning Visualization

# %%
import plotly
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_slice(study)

# %% [markdown]
# ### F1 score Tunning

# %%
args_trial['evaluation_function']='f1_score'

study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.HyperbandPruner(min_resource=3))

models_hyper_optim_optuna.start_optimize_objective(study, args_trial,
                                                   mlp_model, models_trainning)
# Out:
# [I 2022-09-27 10:33:23,074] A new study created in memory with name: no-name-839ae5a7-1e40-41e9-8849-801db8f0a747
# c:\Users\androgo\anaconda3\envs\pytorch_env\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning:
#
# Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=121, bias=True)
#   (bn1): BatchNorm1d(121, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2681402577907979, inplace=False)
#   (lin2): Linear(in_features=121, out_features=245, bias=True)
#   (bn2): BatchNorm1d(245, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.48599705249105063, inplace=False)
#   (lin3): Linear(in_features=245, out_features=105, bias=True)
#   (bn3): BatchNorm1d(105, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3040748927836861, inplace=False)
#   (lin4): Linear(in_features=105, out_features=194, bias=True)
#   (bn4): BatchNorm1d(194, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.11211905086080703, inplace=False)
#   (lin5): Linear(in_features=194, out_features=131, bias=True)
#   (bn5): BatchNorm1d(131, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.4785721131495211, inplace=False)
#   (lin6): Linear(in_features=131, out_features=112, bias=True)
#   (bn6): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.16659094626687582, inplace=False)
#   (lin7): Linear(in_features=112, out_features=207, bias=True)
#   (bn7): BatchNorm1d(207, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.3497149812243051, inplace=False)
#   (lin8): Linear(in_features=207, out_features=150, bias=True)
#   (bn8): BatchNorm1d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.313852240607855, inplace=False)
#   (lin9): Linear(in_features=150, out_features=218, bias=True)
#   (bn9): BatchNorm1d(218, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.49957040241218686, inplace=False)
#   (fc_output): Linear(in_features=218, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 26.74it/s]
# 100%|██████████| 46/46 [00:01<00:00, 32.59it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.95it/s]
# 100%|██████████| 46/46 [00:01<00:00, 34.67it/s]
# 100%|██████████| 46/46 [00:01<00:00, 33.70it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.44it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.16it/s]
# Train set: Average loss: 0.0681, Average accuracy: 2.8477%,
#  	 Average f1_score: 0.0673, Average Area Under ROC: 0.4965
# 100%|██████████| 46/46 [00:00<00:00, 95.99it/s]
# [I 2022-09-27 10:33:33,513] Trial 0 finished with value: 0.060457177460193634 and parameters: {'n_layers': 9, 'n_units_l0': 121, 'dropout_l0': 0.2681402577907979, 'n_units_l1': 245, 'dropout_l1': 0.48599705249105063, 'n_units_l2': 105, 'dropout_l2': 0.3040748927836861, 'n_units_l3': 194, 'dropout_l3': 0.11211905086080703, 'n_units_l4': 131, 'dropout_l4': 0.4785721131495211, 'n_units_l5': 112, 'dropout_l5': 0.16659094626687582, 'n_units_l6': 207, 'dropout_l6': 0.3497149812243051, 'n_units_l7': 150, 'dropout_l7': 0.313852240607855, 'n_units_l8': 218, 'dropout_l8': 0.49957040241218686, 'learning_rate': 0.00535243914353392, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.060457177460193634.
# Test set: Average loss: 2.8010, Average accuracy: 0.0632%,
#  	  Average f1_score: 0.0605, Average Area Under ROC: 0.5019
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=33, bias=True)
#   (bn1): BatchNorm1d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.10321525077220182, inplace=False)
#   (lin2): Linear(in_features=33, out_features=77, bias=True)
#   (bn2): BatchNorm1d(77, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.1600828433195265, inplace=False)
#   (lin3): Linear(in_features=77, out_features=54, bias=True)
#   (bn3): BatchNorm1d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.1280272939993639, inplace=False)
#   (lin4): Linear(in_features=54, out_features=139, bias=True)
#   (bn4): BatchNorm1d(139, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.19442255236324846, inplace=False)
#   (lin5): Linear(in_features=139, out_features=214, bias=True)
#   (bn5): BatchNorm1d(214, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.363979289399155, inplace=False)
#   (lin6): Linear(in_features=214, out_features=242, bias=True)
#   (bn6): BatchNorm1d(242, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.24599068634147808, inplace=False)
#   (lin7): Linear(in_features=242, out_features=116, bias=True)
#   (bn7): BatchNorm1d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.16461813415780246, inplace=False)
#   (lin8): Linear(in_features=116, out_features=238, bias=True)
#   (bn8): BatchNorm1d(238, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.2252727516949943, inplace=False)
#   (lin9): Linear(in_features=238, out_features=245, bias=True)
#   (bn9): BatchNorm1d(245, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.4857774684476631, inplace=False)
#   (fc_output): Linear(in_features=245, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 44.93it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.07it/s]
# 100%|██████████| 46/46 [00:00<00:00, 47.64it/s]
# 100%|██████████| 46/46 [00:00<00:00, 47.26it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.45it/s]
# 100%|██████████| 46/46 [00:00<00:00, 49.26it/s]
# 100%|██████████| 46/46 [00:00<00:00, 53.46it/s]
# Train set: Average loss: 0.0674, Average accuracy: 2.8990%,
#  	 Average f1_score: 0.0671, Average Area Under ROC: 0.5027
# 100%|██████████| 46/46 [00:00<00:00, 100.01it/s]
# [I 2022-09-27 10:33:40,956] Trial 1 finished with value: 0.059420350939035416 and parameters: {'n_layers': 9, 'n_units_l0': 33, 'dropout_l0': 0.10321525077220182, 'n_units_l1': 77, 'dropout_l1': 0.1600828433195265, 'n_units_l2': 54, 'dropout_l2': 0.1280272939993639, 'n_units_l3': 139, 'dropout_l3': 0.19442255236324846, 'n_units_l4': 214, 'dropout_l4': 0.363979289399155, 'n_units_l5': 242, 'dropout_l5': 0.24599068634147808, 'n_units_l6': 116, 'dropout_l6': 0.16461813415780246, 'n_units_l7': 238, 'dropout_l7': 0.2252727516949943, 'n_units_l8': 245, 'dropout_l8': 0.4857774684476631, 'learning_rate': 0.09683081578959292, 'optimizer': 'SGD'}. Best is trial 0 with value: 0.060457177460193634.
# Test set: Average loss: 2.7814, Average accuracy: 0.0611%,
#  	  Average f1_score: 0.0594, Average Area Under ROC: 0.5004
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=61, bias=True)
#   (bn1): BatchNorm1d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.453456424828926, inplace=False)
#   (lin2): Linear(in_features=61, out_features=120, bias=True)
#   (bn2): BatchNorm1d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.10501778773263935, inplace=False)
#   (lin3): Linear(in_features=120, out_features=160, bias=True)
#   (bn3): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.4841750367566269, inplace=False)
#   (lin4): Linear(in_features=160, out_features=224, bias=True)
#   (bn4): BatchNorm1d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.15273595871255702, inplace=False)
#   (lin5): Linear(in_features=224, out_features=135, bias=True)
#   (bn5): BatchNorm1d(135, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.2911104613653799, inplace=False)
#   (lin6): Linear(in_features=135, out_features=148, bias=True)
#   (bn6): BatchNorm1d(148, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.17503639062937545, inplace=False)
#   (lin7): Linear(in_features=148, out_features=124, bias=True)
#   (bn7): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.23264187541992065, inplace=False)
#   (lin8): Linear(in_features=124, out_features=97, bias=True)
#   (bn8): BatchNorm1d(97, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.30363111190554937, inplace=False)
#   (lin9): Linear(in_features=97, out_features=87, bias=True)
#   (bn9): BatchNorm1d(87, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.4037015297831912, inplace=False)
#   (fc_output): Linear(in_features=87, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 29.69it/s]
# 100%|██████████| 46/46 [00:01<00:00, 34.74it/s]
# 100%|██████████| 46/46 [00:01<00:00, 38.47it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.08it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.82it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.94it/s]
# 100%|██████████| 46/46 [00:01<00:00, 36.47it/s]
# Train set: Average loss: 0.0663, Average accuracy: 2.7508%,
#  	 Average f1_score: 0.0652, Average Area Under ROC: 0.5065
# 100%|██████████| 46/46 [00:00<00:00, 95.96it/s]
# [I 2022-09-27 10:33:50,730] Trial 2 finished with value: 0.05864206701517105 and parameters: {'n_layers': 9, 'n_units_l0': 61, 'dropout_l0': 0.453456424828926, 'n_units_l1': 120, 'dropout_l1': 0.10501778773263935, 'n_units_l2': 160, 'dropout_l2': 0.4841750367566269, 'n_units_l3': 224, 'dropout_l3': 0.15273595871255702, 'n_units_l4': 135, 'dropout_l4': 0.2911104613653799, 'n_units_l5': 148, 'dropout_l5': 0.17503639062937545, 'n_units_l6': 124, 'dropout_l6': 0.23264187541992065, 'n_units_l7': 97, 'dropout_l7': 0.30363111190554937, 'n_units_l8': 87, 'dropout_l8': 0.4037015297831912, 'learning_rate': 0.015311525440968816, 'optimizer': 'Adam'}. Best is trial 0 with value: 0.060457177460193634.
# Test set: Average loss: 2.7429, Average accuracy: 0.0632%,
#  	  Average f1_score: 0.0586, Average Area Under ROC: 0.4834
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=97, bias=True)
#   (bn1): BatchNorm1d(97, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.16741908541102157, inplace=False)
#   (lin2): Linear(in_features=97, out_features=176, bias=True)
#   (bn2): BatchNorm1d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.3740154822526718, inplace=False)
#   (lin3): Linear(in_features=176, out_features=36, bias=True)
#   (bn3): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.4177301334530622, inplace=False)
#   (fc_output): Linear(in_features=36, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 55.67it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.83it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.32it/s]
# 100%|██████████| 46/46 [00:00<00:00, 69.51it/s]
# [I 2022-09-27 10:33:54,052] Trial 3 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=236, bias=True)
#   (bn1): BatchNorm1d(236, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21439208164570675, inplace=False)
#   (lin2): Linear(in_features=236, out_features=53, bias=True)
#   (bn2): BatchNorm1d(53, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.18331212734317726, inplace=False)
#   (lin3): Linear(in_features=53, out_features=98, bias=True)
#   (bn3): BatchNorm1d(98, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.15224556988324728, inplace=False)
#   (lin4): Linear(in_features=98, out_features=31, bias=True)
#   (bn4): BatchNorm1d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4267599846438018, inplace=False)
#   (lin5): Linear(in_features=31, out_features=142, bias=True)
#   (bn5): BatchNorm1d(142, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.2633230275236289, inplace=False)
#   (lin6): Linear(in_features=142, out_features=148, bias=True)
#   (bn6): BatchNorm1d(148, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.10228897797919255, inplace=False)
#   (lin7): Linear(in_features=148, out_features=246, bias=True)
#   (bn7): BatchNorm1d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.18547522881309406, inplace=False)
#   (lin8): Linear(in_features=246, out_features=146, bias=True)
#   (bn8): BatchNorm1d(146, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.37927672348214625, inplace=False)
#   (lin9): Linear(in_features=146, out_features=209, bias=True)
#   (bn9): BatchNorm1d(209, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.11495499725292313, inplace=False)
#   (fc_output): Linear(in_features=209, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 37.68it/s]
# 100%|██████████| 46/46 [00:01<00:00, 37.50it/s]
# 100%|██████████| 46/46 [00:01<00:00, 34.57it/s]
# 100%|██████████| 46/46 [00:01<00:00, 34.30it/s]
# [I 2022-09-27 10:33:59,319] Trial 4 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=79, bias=True)
#   (bn1): BatchNorm1d(79, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2736732565893514, inplace=False)
#   (lin2): Linear(in_features=79, out_features=59, bias=True)
#   (bn2): BatchNorm1d(59, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.430080638991328, inplace=False)
#   (lin3): Linear(in_features=59, out_features=226, bias=True)
#   (bn3): BatchNorm1d(226, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.25210486768358886, inplace=False)
#   (lin4): Linear(in_features=226, out_features=207, bias=True)
#   (bn4): BatchNorm1d(207, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.41350763172999583, inplace=False)
#   (lin5): Linear(in_features=207, out_features=247, bias=True)
#   (bn5): BatchNorm1d(247, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3665102816461402, inplace=False)
#   (lin6): Linear(in_features=247, out_features=35, bias=True)
#   (bn6): BatchNorm1d(35, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.468960415973416, inplace=False)
#   (lin7): Linear(in_features=35, out_features=207, bias=True)
#   (bn7): BatchNorm1d(207, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.14144283182083664, inplace=False)
#   (lin8): Linear(in_features=207, out_features=239, bias=True)
#   (bn8): BatchNorm1d(239, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.24982758643178601, inplace=False)
#   (lin9): Linear(in_features=239, out_features=102, bias=True)
#   (bn9): BatchNorm1d(102, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.22973340777620505, inplace=False)
#   (fc_output): Linear(in_features=102, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 42.04it/s]
# 100%|██████████| 46/46 [00:01<00:00, 42.67it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.30it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.71it/s]
# [I 2022-09-27 10:34:03,744] Trial 5 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=87, bias=True)
#   (bn1): BatchNorm1d(87, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.28597425987862046, inplace=False)
#   (lin2): Linear(in_features=87, out_features=255, bias=True)
#   (bn2): BatchNorm1d(255, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.37165179942209925, inplace=False)
#   (lin3): Linear(in_features=255, out_features=212, bias=True)
#   (bn3): BatchNorm1d(212, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.11380315795890437, inplace=False)
#   (lin4): Linear(in_features=212, out_features=82, bias=True)
#   (bn4): BatchNorm1d(82, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.3592546559659483, inplace=False)
#   (lin5): Linear(in_features=82, out_features=145, bias=True)
#   (bn5): BatchNorm1d(145, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.2631823658936363, inplace=False)
#   (lin6): Linear(in_features=145, out_features=40, bias=True)
#   (bn6): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.4794821391879215, inplace=False)
#   (fc_output): Linear(in_features=40, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 66.04it/s]
# 100%|██████████| 46/46 [00:00<00:00, 65.54it/s]
# 100%|██████████| 46/46 [00:00<00:00, 66.20it/s]
# 100%|██████████| 46/46 [00:00<00:00, 64.59it/s]
# [I 2022-09-27 10:34:06,675] Trial 6 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=71, bias=True)
#   (bn1): BatchNorm1d(71, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4520672969098106, inplace=False)
#   (lin2): Linear(in_features=71, out_features=101, bias=True)
#   (bn2): BatchNorm1d(101, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4375175154933274, inplace=False)
#   (lin3): Linear(in_features=101, out_features=136, bias=True)
#   (bn3): BatchNorm1d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.4357016680599799, inplace=False)
#   (lin4): Linear(in_features=136, out_features=115, bias=True)
#   (bn4): BatchNorm1d(115, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4988640115721048, inplace=False)
#   (fc_output): Linear(in_features=115, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 58.98it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.78it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.39it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.07it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.36it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.99it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.71it/s]
# Train set: Average loss: 0.0669, Average accuracy: 2.7693%,
#  	 Average f1_score: 0.0645, Average Area Under ROC: 0.4977
# 100%|██████████| 46/46 [00:00<00:00, 128.08it/s]
# [I 2022-09-27 10:34:12,682] Trial 7 finished with value: 0.07124469429254532 and parameters: {'n_layers': 4, 'n_units_l0': 71, 'dropout_l0': 0.4520672969098106, 'n_units_l1': 101, 'dropout_l1': 0.4375175154933274, 'n_units_l2': 136, 'dropout_l2': 0.4357016680599799, 'n_units_l3': 115, 'dropout_l3': 0.4988640115721048, 'learning_rate': 0.026369733912135093, 'optimizer': 'Adam'}. Best is trial 7 with value: 0.07124469429254532.
# Test set: Average loss: 2.7222, Average accuracy: 0.0754%,
#  	  Average f1_score: 0.0712, Average Area Under ROC: 0.4921
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=25, bias=True)
#   (bn1): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.35533844085383126, inplace=False)
#   (lin2): Linear(in_features=25, out_features=140, bias=True)
#   (bn2): BatchNorm1d(140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.3669201207123468, inplace=False)
#   (lin3): Linear(in_features=140, out_features=114, bias=True)
#   (bn3): BatchNorm1d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.15539987923940976, inplace=False)
#   (fc_output): Linear(in_features=114, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 63.88it/s]
# 100%|██████████| 46/46 [00:00<00:00, 51.71it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.33it/s]
# 100%|██████████| 46/46 [00:00<00:00, 68.01it/s]
# [I 2022-09-27 10:34:15,837] Trial 8 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=101, bias=True)
#   (bn1): BatchNorm1d(101, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.26609436079395943, inplace=False)
#   (lin2): Linear(in_features=101, out_features=130, bias=True)
#   (bn2): BatchNorm1d(130, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.10935171243853686, inplace=False)
#   (lin3): Linear(in_features=130, out_features=35, bias=True)
#   (bn3): BatchNorm1d(35, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.376081793236131, inplace=False)
#   (lin4): Linear(in_features=35, out_features=181, bias=True)
#   (bn4): BatchNorm1d(181, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.30485605354828926, inplace=False)
#   (lin5): Linear(in_features=181, out_features=133, bias=True)
#   (bn5): BatchNorm1d(133, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3174671994083641, inplace=False)
#   (lin6): Linear(in_features=133, out_features=164, bias=True)
#   (bn6): BatchNorm1d(164, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.2931637209383966, inplace=False)
#   (lin7): Linear(in_features=164, out_features=229, bias=True)
#   (bn7): BatchNorm1d(229, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.4136082758782621, inplace=False)
#   (fc_output): Linear(in_features=229, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 61.12it/s]
# 100%|██████████| 46/46 [00:00<00:00, 58.80it/s]
# 100%|██████████| 46/46 [00:00<00:00, 59.56it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.99it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.28it/s]
# 100%|██████████| 46/46 [00:00<00:00, 58.29it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.08it/s]
# Train set: Average loss: 0.0646, Average accuracy: 2.8963%,
#  	 Average f1_score: 0.0643, Average Area Under ROC: 0.4975
# 100%|██████████| 46/46 [00:00<00:00, 107.81it/s]
# [I 2022-09-27 10:34:21,948] Trial 9 finished with value: 0.06589959561824799 and parameters: {'n_layers': 7, 'n_units_l0': 101, 'dropout_l0': 0.26609436079395943, 'n_units_l1': 130, 'dropout_l1': 0.10935171243853686, 'n_units_l2': 35, 'dropout_l2': 0.376081793236131, 'n_units_l3': 181, 'dropout_l3': 0.30485605354828926, 'n_units_l4': 133, 'dropout_l4': 0.3174671994083641, 'n_units_l5': 164, 'dropout_l5': 0.2931637209383966, 'n_units_l6': 229, 'dropout_l6': 0.4136082758782621, 'learning_rate': 0.06592866948721085, 'optimizer': 'SGD'}. Best is trial 7 with value: 0.07124469429254532.
# Test set: Average loss: 2.7263, Average accuracy: 0.0652%,
#  	  Average f1_score: 0.0659, Average Area Under ROC: 0.4942
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=171, bias=True)
#   (bn1): BatchNorm1d(171, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.48958288881913137, inplace=False)
#   (lin2): Linear(in_features=171, out_features=190, bias=True)
#   (bn2): BatchNorm1d(190, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.2674833042633845, inplace=False)
#   (fc_output): Linear(in_features=190, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 84.08it/s]
# 100%|██████████| 46/46 [00:00<00:00, 63.48it/s]
# 100%|██████████| 46/46 [00:00<00:00, 73.86it/s]
# 100%|██████████| 46/46 [00:00<00:00, 83.25it/s]
# [I 2022-09-27 10:34:24,544] Trial 10 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=160, bias=True)
#   (bn1): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.36173312794799284, inplace=False)
#   (lin2): Linear(in_features=160, out_features=102, bias=True)
#   (bn2): BatchNorm1d(102, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.25571466083278477, inplace=False)
#   (lin3): Linear(in_features=102, out_features=167, bias=True)
#   (bn3): BatchNorm1d(167, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3828512145449504, inplace=False)
#   (lin4): Linear(in_features=167, out_features=130, bias=True)
#   (bn4): BatchNorm1d(130, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.49376929840530653, inplace=False)
#   (lin5): Linear(in_features=130, out_features=30, bias=True)
#   (bn5): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.11092466244066784, inplace=False)
#   (lin6): Linear(in_features=30, out_features=225, bias=True)
#   (bn6): BatchNorm1d(225, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.3649589553661683, inplace=False)
#   (fc_output): Linear(in_features=225, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 64.98it/s]
# 100%|██████████| 46/46 [00:00<00:00, 64.84it/s]
# 100%|██████████| 46/46 [00:00<00:00, 54.28it/s]
# 100%|██████████| 46/46 [00:00<00:00, 47.70it/s]
# [I 2022-09-27 10:34:27,975] Trial 11 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=131, bias=True)
#   (bn1): BatchNorm1d(131, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.39165494510891896, inplace=False)
#   (lin2): Linear(in_features=131, out_features=26, bias=True)
#   (bn2): BatchNorm1d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.49272532149201864, inplace=False)
#   (lin3): Linear(in_features=26, out_features=69, bias=True)
#   (bn3): BatchNorm1d(69, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3775375903374387, inplace=False)
#   (lin4): Linear(in_features=69, out_features=165, bias=True)
#   (bn4): BatchNorm1d(165, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.2561538464705134, inplace=False)
#   (lin5): Linear(in_features=165, out_features=58, bias=True)
#   (bn5): BatchNorm1d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.1424835233154168, inplace=False)
#   (fc_output): Linear(in_features=58, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 56.26it/s]
# 100%|██████████| 46/46 [00:00<00:00, 54.86it/s]
# 100%|██████████| 46/46 [00:00<00:00, 61.85it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.45it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.37it/s]
# 100%|██████████| 46/46 [00:00<00:00, 71.29it/s]
# 100%|██████████| 46/46 [00:00<00:00, 69.71it/s]
# Train set: Average loss: 0.0705, Average accuracy: 2.8364%,
#  	 Average f1_score: 0.0701, Average Area Under ROC: 0.5020
# 100%|██████████| 46/46 [00:00<00:00, 120.57it/s]
# [I 2022-09-27 10:34:33,675] Trial 12 finished with value: 0.061529628932476044 and parameters: {'n_layers': 5, 'n_units_l0': 131, 'dropout_l0': 0.39165494510891896, 'n_units_l1': 26, 'dropout_l1': 0.49272532149201864, 'n_units_l2': 69, 'dropout_l2': 0.3775375903374387, 'n_units_l3': 165, 'dropout_l3': 0.2561538464705134, 'n_units_l4': 58, 'dropout_l4': 0.1424835233154168, 'learning_rate': 0.022990942743317023, 'optimizer': 'SGD'}. Best is trial 7 with value: 0.07124469429254532.
# Test set: Average loss: 2.7457, Average accuracy: 0.0639%,
#  	  Average f1_score: 0.0615, Average Area Under ROC: 0.4886
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=213, bias=True)
#   (bn1): BatchNorm1d(213, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.42227307096481315, inplace=False)
#   (lin2): Linear(in_features=213, out_features=177, bias=True)
#   (bn2): BatchNorm1d(177, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.3160359224547145, inplace=False)
#   (lin3): Linear(in_features=177, out_features=251, bias=True)
#   (bn3): BatchNorm1d(251, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.4985997247613665, inplace=False)
#   (lin4): Linear(in_features=251, out_features=99, bias=True)
#   (bn4): BatchNorm1d(99, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.2929914435447101, inplace=False)
#   (lin5): Linear(in_features=99, out_features=85, bias=True)
#   (bn5): BatchNorm1d(85, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.48506053608898286, inplace=False)
#   (fc_output): Linear(in_features=85, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 61.41it/s]
# 100%|██████████| 46/46 [00:00<00:00, 54.00it/s]
# 100%|██████████| 46/46 [00:00<00:00, 61.28it/s]
# 100%|██████████| 46/46 [00:00<00:00, 69.36it/s]
# [I 2022-09-27 10:34:36,870] Trial 13 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=61, bias=True)
#   (bn1): BatchNorm1d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3295990828945514, inplace=False)
#   (lin2): Linear(in_features=61, out_features=94, bias=True)
#   (bn2): BatchNorm1d(94, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.20250467888973667, inplace=False)
#   (lin3): Linear(in_features=94, out_features=25, bias=True)
#   (bn3): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.30634977566025057, inplace=False)
#   (lin4): Linear(in_features=25, out_features=173, bias=True)
#   (bn4): BatchNorm1d(173, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.49896282654981483, inplace=False)
#   (lin5): Linear(in_features=173, out_features=195, bias=True)
#   (bn5): BatchNorm1d(195, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.1822477682859409, inplace=False)
#   (lin6): Linear(in_features=195, out_features=202, bias=True)
#   (bn6): BatchNorm1d(202, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.33228067987736964, inplace=False)
#   (lin7): Linear(in_features=202, out_features=56, bias=True)
#   (bn7): BatchNorm1d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.4856076045967437, inplace=False)
#   (fc_output): Linear(in_features=56, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 49.73it/s]
# 100%|██████████| 46/46 [00:00<00:00, 52.18it/s]
# 100%|██████████| 46/46 [00:00<00:00, 52.76it/s]
# 100%|██████████| 46/46 [00:00<00:00, 50.57it/s]
# [I 2022-09-27 10:34:40,652] Trial 14 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=113, bias=True)
#   (bn1): BatchNorm1d(113, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21454191718527593, inplace=False)
#   (lin2): Linear(in_features=113, out_features=140, bias=True)
#   (bn2): BatchNorm1d(140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.11736984111485299, inplace=False)
#   (lin3): Linear(in_features=140, out_features=187, bias=True)
#   (bn3): BatchNorm1d(187, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.43071780192405207, inplace=False)
#   (lin4): Linear(in_features=187, out_features=239, bias=True)
#   (bn4): BatchNorm1d(239, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.35415683860710767, inplace=False)
#   (lin5): Linear(in_features=239, out_features=185, bias=True)
#   (bn5): BatchNorm1d(185, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.37306116707380843, inplace=False)
#   (lin6): Linear(in_features=185, out_features=96, bias=True)
#   (bn6): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.3931621651002711, inplace=False)
#   (lin7): Linear(in_features=96, out_features=181, bias=True)
#   (bn7): BatchNorm1d(181, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.4123839378713842, inplace=False)
#   (fc_output): Linear(in_features=181, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 39.72it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.60it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.66it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.72it/s]
# [I 2022-09-27 10:34:45,198] Trial 15 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=160, bias=True)
#   (bn1): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2241685609435386, inplace=False)
#   (lin2): Linear(in_features=160, out_features=208, bias=True)
#   (bn2): BatchNorm1d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.42855645624883637, inplace=False)
#   (lin3): Linear(in_features=208, out_features=135, bias=True)
#   (bn3): BatchNorm1d(135, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3466907709068966, inplace=False)
#   (lin4): Linear(in_features=135, out_features=89, bias=True)
#   (bn4): BatchNorm1d(89, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.2224810845736569, inplace=False)
#   (fc_output): Linear(in_features=89, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 78.27it/s]
# 100%|██████████| 46/46 [00:00<00:00, 75.92it/s]
# 100%|██████████| 46/46 [00:00<00:00, 78.51it/s]
# 100%|██████████| 46/46 [00:00<00:00, 79.42it/s]
# [I 2022-09-27 10:34:47,716] Trial 16 pruned.

# %%
trials_finished = study.get_trials()
print('number of trials finished: ', len(trials_finished),'\n')

print('number of the best trial: ',study.best_trial.number)

for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# number of trials finished:  17
#
# number of the best trial:  7
# n_layers: 7
# n_units_l0: 237
# dropout_l0: 0.4873166291124967
# n_units_l1: 249
# dropout_l1: 0.1353662459751821
# n_units_l2: 89
# dropout_l2: 0.23364429629448566
# n_units_l3: 26
# dropout_l3: 0.1015215845364244
# n_units_l4: 255
# dropout_l4: 0.3328424939823516
# n_units_l5: 231
# dropout_l5: 0.13097556405103974
# n_units_l6: 182
# dropout_l6: 0.22358444942948233
# learning_rate: 0.0333735696692182
# optimizer: SGD

# %% [markdown]
# ### Tuning Visualization

# %%
import plotly
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_slice(study)
