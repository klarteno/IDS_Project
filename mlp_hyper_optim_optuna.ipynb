# %%
# %reload_ext autoreload
# %autoreload 2

import optuna
import torch

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ##### Hyperparameter Tuning with Accuracy Pruning </br>

# %%
import models_hyper_optim_optuna
import models
import neural_net_model_train


def setFolders(evaluation_function):
    #set folders where models will be saved
    mlp_path_root_model = "models\mlp\\"+ evaluation_function
    models_hyper_optim_optuna.createFolder(mlp_path_root_model)  
    return mlp_path_root_model + "\mlp_"

# %%
channels = 1
batch_size= 32

args_model = {
    'number_of_classes':models_hyper_optim_optuna.number_of_classes, 
    'input_shape' : (32, channels, models_hyper_optim_optuna.input_size)
    }


args_trial = {
    'max_epochs' : 7,
    'no_trials': 7, 
    'evaluation_function':'accuracy', 
    'USE_AUTOMATIC_MIXED_PRECISION':True
}

#set models that will be used for tunning
mlp_model = models.MlpModel(args_model)
models_trainning = neural_net_model_train.ModelsTrainning()

# %% [markdown]
# ### Accuracy Tunning

# %%
from time import time

start = time()

args_trial['evaluation_function']='accuracy'
path_models_id = setFolders(args_trial['evaluation_function'])

study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.HyperbandPruner(min_resource=3))

'''study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.MedianPruner())'''

models_hyper_optim_optuna.start_optimize_objective(study, args_trial,
                                                   path_models_id,
                                                   mlp_model, 
                                                   models_trainning)
end = time()
# Out:
# [I 2022-09-27 16:46:37,594] A new study created in memory with name: no-name-6092d32c-1fc3-49a2-bb20-69ed4cfdfd9a
# ModelsInterface empty_models
# c:\Users\androgo\anaconda3\envs\pytorch_env\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning:
#
# Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=210, bias=True)
#   (bn1): BatchNorm1d(210, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.1602458726301168, inplace=False)
#   (lin2): Linear(in_features=210, out_features=167, bias=True)
#   (bn2): BatchNorm1d(167, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.48241946037053807, inplace=False)
#   (fc_output): Linear(in_features=167, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 76.16it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.32it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.84it/s]
# 100%|██████████| 46/46 [00:00<00:00, 51.75it/s]
# 100%|██████████| 46/46 [00:00<00:00, 54.04it/s]
# 100%|██████████| 46/46 [00:00<00:00, 50.62it/s]
# 100%|██████████| 46/46 [00:00<00:00, 74.59it/s]
# Train set: Average loss: 0.0672, Average accuracy: 2.8897%,
#  	 Average f1_score: 0.0670, Average Area Under ROC: 0.5040
# 100%|██████████| 46/46 [00:00<00:00, 116.65it/s]
# [I 2022-09-27 16:46:44,137] Trial 0 finished with value: 0.05842391401529312 and parameters: {'n_layers': 2, 'n_units_l0': 210, 'dropout_l0': 0.1602458726301168, 'n_units_l1': 167, 'dropout_l1': 0.48241946037053807, 'learning_rate': 0.05030413088531113, 'optimizer': 'SGD'}. Best is trial 0 with value: 0.05842391401529312.
# Test set: Average loss: 2.7815, Average accuracy: 0.0584%,
#  	  Average f1_score: 0.0590, Average Area Under ROC: 0.4974
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=46, bias=True)
#   (bn1): BatchNorm1d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.2537854297999568, inplace=False)
#   (lin2): Linear(in_features=46, out_features=153, bias=True)
#   (bn2): BatchNorm1d(153, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.306705998571277, inplace=False)
#   (fc_output): Linear(in_features=153, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 86.94it/s]
# 100%|██████████| 46/46 [00:00<00:00, 83.59it/s]
# 100%|██████████| 46/46 [00:00<00:00, 80.86it/s]
# 100%|██████████| 46/46 [00:00<00:00, 82.75it/s]
# 100%|██████████| 46/46 [00:00<00:00, 85.86it/s]
# 100%|██████████| 46/46 [00:00<00:00, 88.04it/s]
# 100%|██████████| 46/46 [00:00<00:00, 75.53it/s]
# Train set: Average loss: 0.0667, Average accuracy: 2.8940%,
#  	 Average f1_score: 0.0637, Average Area Under ROC: 0.5001
# 100%|██████████| 46/46 [00:00<00:00, 123.42it/s]
# [I 2022-09-27 16:46:48,656] Trial 1 finished with value: 0.06861413270235062 and parameters: {'n_layers': 2, 'n_units_l0': 46, 'dropout_l0': 0.2537854297999568, 'n_units_l1': 153, 'dropout_l1': 0.306705998571277, 'learning_rate': 0.056846989480610705, 'optimizer': 'RMSprop'}. Best is trial 1 with value: 0.06861413270235062.
# Test set: Average loss: 2.7317, Average accuracy: 0.0686%,
#  	  Average f1_score: 0.0631, Average Area Under ROC: 0.4997
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=132, bias=True)
#   (bn1): BatchNorm1d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3177073865653305, inplace=False)
#   (lin2): Linear(in_features=132, out_features=155, bias=True)
#   (bn2): BatchNorm1d(155, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4369792022829979, inplace=False)
#   (lin3): Linear(in_features=155, out_features=36, bias=True)
#   (bn3): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.2223535243560658, inplace=False)
#   (lin4): Linear(in_features=36, out_features=114, bias=True)
#   (bn4): BatchNorm1d(114, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.20518576324820215, inplace=False)
#   (lin5): Linear(in_features=114, out_features=176, bias=True)
#   (bn5): BatchNorm1d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.1281504694783073, inplace=False)
#   (lin6): Linear(in_features=176, out_features=124, bias=True)
#   (bn6): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.34017665690399823, inplace=False)
#   (lin7): Linear(in_features=124, out_features=227, bias=True)
#   (bn7): BatchNorm1d(227, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.22189160751583425, inplace=False)
#   (lin8): Linear(in_features=227, out_features=112, bias=True)
#   (bn8): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.38864537534287646, inplace=False)
#   (lin9): Linear(in_features=112, out_features=101, bias=True)
#   (bn9): BatchNorm1d(101, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.30672992122504017, inplace=False)
#   (fc_output): Linear(in_features=101, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 36.00it/s]
# 100%|██████████| 46/46 [00:01<00:00, 39.55it/s]
# 100%|██████████| 46/46 [00:01<00:00, 40.11it/s]
# 100%|██████████| 46/46 [00:01<00:00, 32.21it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.88it/s]
# 100%|██████████| 46/46 [00:01<00:00, 40.67it/s]
# 100%|██████████| 46/46 [00:01<00:00, 39.38it/s]
# Train set: Average loss: 0.0657, Average accuracy: 2.7483%,
#  	 Average f1_score: 0.0621, Average Area Under ROC: 0.5021
# 100%|██████████| 46/46 [00:00<00:00, 95.70it/s]
# [I 2022-09-27 16:46:58,057] Trial 2 finished with value: 0.07133152335882187 and parameters: {'n_layers': 9, 'n_units_l0': 132, 'dropout_l0': 0.3177073865653305, 'n_units_l1': 155, 'dropout_l1': 0.4369792022829979, 'n_units_l2': 36, 'dropout_l2': 0.2223535243560658, 'n_units_l3': 114, 'dropout_l3': 0.20518576324820215, 'n_units_l4': 176, 'dropout_l4': 0.1281504694783073, 'n_units_l5': 124, 'dropout_l5': 0.34017665690399823, 'n_units_l6': 227, 'dropout_l6': 0.22189160751583425, 'n_units_l7': 112, 'dropout_l7': 0.38864537534287646, 'n_units_l8': 101, 'dropout_l8': 0.30672992122504017, 'learning_rate': 0.03547252206469744, 'optimizer': 'Adam'}. Best is trial 2 with value: 0.07133152335882187.
# Test set: Average loss: 2.7136, Average accuracy: 0.0713%,
#  	  Average f1_score: 0.0630, Average Area Under ROC: 0.5115
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=52, bias=True)
#   (bn1): BatchNorm1d(52, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3919519968193327, inplace=False)
#   (lin2): Linear(in_features=52, out_features=99, bias=True)
#   (bn2): BatchNorm1d(99, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.29949597455860705, inplace=False)
#   (lin3): Linear(in_features=99, out_features=244, bias=True)
#   (bn3): BatchNorm1d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.4626738231504359, inplace=False)
#   (lin4): Linear(in_features=244, out_features=247, bias=True)
#   (bn4): BatchNorm1d(247, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.19285911408126313, inplace=False)
#   (lin5): Linear(in_features=247, out_features=146, bias=True)
#   (bn5): BatchNorm1d(146, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.11834394249930824, inplace=False)
#   (lin6): Linear(in_features=146, out_features=37, bias=True)
#   (bn6): BatchNorm1d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.15435656901905748, inplace=False)
#   (lin7): Linear(in_features=37, out_features=132, bias=True)
#   (bn7): BatchNorm1d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.23426977284962805, inplace=False)
#   (fc_output): Linear(in_features=132, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 41.37it/s]
# 100%|██████████| 46/46 [00:01<00:00, 42.64it/s]
# 100%|██████████| 46/46 [00:00<00:00, 58.38it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.58it/s]
# [I 2022-09-27 16:47:01,921] Trial 3 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=234, bias=True)
#   (bn1): BatchNorm1d(234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.36368036014616645, inplace=False)
#   (lin2): Linear(in_features=234, out_features=200, bias=True)
#   (bn2): BatchNorm1d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.38558184667232376, inplace=False)
#   (lin3): Linear(in_features=200, out_features=171, bias=True)
#   (bn3): BatchNorm1d(171, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3905057897586265, inplace=False)
#   (lin4): Linear(in_features=171, out_features=27, bias=True)
#   (bn4): BatchNorm1d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.45855772822116203, inplace=False)
#   (lin5): Linear(in_features=27, out_features=84, bias=True)
#   (bn5): BatchNorm1d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.4519559865954479, inplace=False)
#   (lin6): Linear(in_features=84, out_features=89, bias=True)
#   (bn6): BatchNorm1d(89, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.31738405937880937, inplace=False)
#   (lin7): Linear(in_features=89, out_features=32, bias=True)
#   (bn7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.32634436560204894, inplace=False)
#   (lin8): Linear(in_features=32, out_features=40, bias=True)
#   (bn8): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.40697807702001665, inplace=False)
#   (lin9): Linear(in_features=40, out_features=134, bias=True)
#   (bn9): BatchNorm1d(134, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel9): LeakyReLU(negative_slope=0.01)
#   (drop9): Dropout(p=0.1442832339309592, inplace=False)
#   (fc_output): Linear(in_features=134, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 47.68it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.75it/s]
# 100%|██████████| 46/46 [00:01<00:00, 38.49it/s]
# 100%|██████████| 46/46 [00:00<00:00, 50.23it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.97it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.31it/s]
# 100%|██████████| 46/46 [00:00<00:00, 51.03it/s]
# Train set: Average loss: 0.0656, Average accuracy: 2.8381%,
#  	 Average f1_score: 0.0652, Average Area Under ROC: 0.5054
# 100%|██████████| 46/46 [00:00<00:00, 96.04it/s]
# [I 2022-09-27 16:47:09,307] Trial 4 finished with value: 0.06182065233588219 and parameters: {'n_layers': 9, 'n_units_l0': 234, 'dropout_l0': 0.36368036014616645, 'n_units_l1': 200, 'dropout_l1': 0.38558184667232376, 'n_units_l2': 171, 'dropout_l2': 0.3905057897586265, 'n_units_l3': 27, 'dropout_l3': 0.45855772822116203, 'n_units_l4': 84, 'dropout_l4': 0.4519559865954479, 'n_units_l5': 89, 'dropout_l5': 0.31738405937880937, 'n_units_l6': 32, 'dropout_l6': 0.32634436560204894, 'n_units_l7': 40, 'dropout_l7': 0.40697807702001665, 'n_units_l8': 134, 'dropout_l8': 0.1442832339309592, 'learning_rate': 0.01980331563065776, 'optimizer': 'SGD'}. Best is trial 2 with value: 0.07133152335882187.
# Test set: Average loss: 2.7246, Average accuracy: 0.0618%,
#  	  Average f1_score: 0.0582, Average Area Under ROC: 0.4986
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=94, bias=True)
#   (bn1): BatchNorm1d(94, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.21265706721416985, inplace=False)
#   (lin2): Linear(in_features=94, out_features=107, bias=True)
#   (bn2): BatchNorm1d(107, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.3763688984279665, inplace=False)
#   (lin3): Linear(in_features=107, out_features=56, bias=True)
#   (bn3): BatchNorm1d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3404383271684175, inplace=False)
#   (fc_output): Linear(in_features=56, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 51.91it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.49it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.57it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.92it/s]
# [I 2022-09-27 16:47:13,182] Trial 5 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=161, bias=True)
#   (bn1): BatchNorm1d(161, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3350506995947687, inplace=False)
#   (lin2): Linear(in_features=161, out_features=113, bias=True)
#   (bn2): BatchNorm1d(113, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.30343587595153904, inplace=False)
#   (lin3): Linear(in_features=113, out_features=181, bias=True)
#   (bn3): BatchNorm1d(181, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.15928959101288764, inplace=False)
#   (lin4): Linear(in_features=181, out_features=123, bias=True)
#   (bn4): BatchNorm1d(123, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.22488824209139824, inplace=False)
#   (fc_output): Linear(in_features=123, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 50.15it/s]
# 100%|██████████| 46/46 [00:00<00:00, 50.95it/s]
# 100%|██████████| 46/46 [00:01<00:00, 41.92it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.25it/s]
# 100%|██████████| 46/46 [00:00<00:00, 63.90it/s]
# 100%|██████████| 46/46 [00:00<00:00, 62.42it/s]
# 100%|██████████| 46/46 [00:00<00:00, 66.40it/s]
# Train set: Average loss: 0.0650, Average accuracy: 2.8372%,
#  	 Average f1_score: 0.0648, Average Area Under ROC: 0.4992
# 100%|██████████| 46/46 [00:00<00:00, 84.17it/s]
# [I 2022-09-27 16:47:20,041] Trial 6 finished with value: 0.06929347664117813 and parameters: {'n_layers': 4, 'n_units_l0': 161, 'dropout_l0': 0.3350506995947687, 'n_units_l1': 113, 'dropout_l1': 0.30343587595153904, 'n_units_l2': 181, 'dropout_l2': 0.15928959101288764, 'n_units_l3': 123, 'dropout_l3': 0.22488824209139824, 'learning_rate': 0.05713648702432272, 'optimizer': 'SGD'}. Best is trial 2 with value: 0.07133152335882187.
# Test set: Average loss: 2.7422, Average accuracy: 0.0693%,
#  	  Average f1_score: 0.0684, Average Area Under ROC: 0.5008

# %%
trials_finished = study.get_trials()
print('number of trials finished: ', len(trials_finished),'\n')

print('number of the best trial: ',study.best_trial.number)

best_trial = study.best_trial
for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# number of trials finished:  7
#
# number of the best trial:  2
# n_layers: 9
# n_units_l0: 132
# dropout_l0: 0.3177073865653305
# n_units_l1: 155
# dropout_l1: 0.4369792022829979
# n_units_l2: 36
# dropout_l2: 0.2223535243560658
# n_units_l3: 114
# dropout_l3: 0.20518576324820215
# n_units_l4: 176
# dropout_l4: 0.1281504694783073
# n_units_l5: 124
# dropout_l5: 0.34017665690399823
# n_units_l6: 227
# dropout_l6: 0.22189160751583425
# n_units_l7: 112
# dropout_l7: 0.38864537534287646
# n_units_l8: 101
# dropout_l8: 0.30672992122504017
# learning_rate: 0.03547252206469744
# optimizer: Adam

# %% [markdown]
# ### Tuning Visualization

# %%
import plotly
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_slice(study)

# %% [markdown]
# ### F1 score Tunning

# %%
args_trial['evaluation_function']='f1_score'
path_models_id = setFolders(args_trial['evaluation_function'])


study = optuna.create_study(direction = "maximize", sampler = optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.HyperbandPruner(min_resource=3))

models_hyper_optim_optuna.start_optimize_objective(study, args_trial,
                                                   path_models_id,
                                                   mlp_model,
                                                   models_trainning)
# Out:
# [I 2022-09-27 16:47:29,680] A new study created in memory with name: no-name-00a4659f-e384-4c3e-a49a-f8e014a0cc74
# c:\Users\androgo\anaconda3\envs\pytorch_env\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning:
#
# Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
# ModelsInterface empty_models
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=202, bias=True)
#   (bn1): BatchNorm1d(202, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.23888073096377904, inplace=False)
#   (lin2): Linear(in_features=202, out_features=30, bias=True)
#   (bn2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.1289031197675613, inplace=False)
#   (lin3): Linear(in_features=30, out_features=254, bias=True)
#   (bn3): BatchNorm1d(254, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.31575786186726323, inplace=False)
#   (lin4): Linear(in_features=254, out_features=233, bias=True)
#   (bn4): BatchNorm1d(233, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.4503245569665334, inplace=False)
#   (fc_output): Linear(in_features=233, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 27.69it/s]
# 100%|██████████| 46/46 [00:01<00:00, 24.74it/s]
# 100%|██████████| 46/46 [00:02<00:00, 22.38it/s]
# 100%|██████████| 46/46 [00:01<00:00, 29.59it/s]
# 100%|██████████| 46/46 [00:01<00:00, 41.42it/s]
# 100%|██████████| 46/46 [00:00<00:00, 51.00it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.31it/s]
# Train set: Average loss: 0.0674, Average accuracy: 2.9245%,
#  	 Average f1_score: 0.0674, Average Area Under ROC: 0.5035
# 100%|██████████| 46/46 [00:00<00:00, 98.13it/s]
# [I 2022-09-27 16:47:40,676] Trial 0 finished with value: 0.06622752547264099 and parameters: {'n_layers': 4, 'n_units_l0': 202, 'dropout_l0': 0.23888073096377904, 'n_units_l1': 30, 'dropout_l1': 0.1289031197675613, 'n_units_l2': 254, 'dropout_l2': 0.31575786186726323, 'n_units_l3': 233, 'dropout_l3': 0.4503245569665334, 'learning_rate': 0.017315098240465465, 'optimizer': 'SGD'}. Best is trial 0 with value: 0.06622752547264099.
# Test set: Average loss: 2.7492, Average accuracy: 0.0666%,
#  	  Average f1_score: 0.0662, Average Area Under ROC: 0.5019
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=98, bias=True)
#   (bn1): BatchNorm1d(98, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3485147967968053, inplace=False)
#   (lin2): Linear(in_features=98, out_features=127, bias=True)
#   (bn2): BatchNorm1d(127, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.152069997281961, inplace=False)
#   (lin3): Linear(in_features=127, out_features=63, bias=True)
#   (bn3): BatchNorm1d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.20602605607056607, inplace=False)
#   (lin4): Linear(in_features=63, out_features=252, bias=True)
#   (bn4): BatchNorm1d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.15311634944425082, inplace=False)
#   (fc_output): Linear(in_features=252, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 47.21it/s]
# 100%|██████████| 46/46 [00:00<00:00, 46.13it/s]
# 100%|██████████| 46/46 [00:00<00:00, 48.58it/s]
# 100%|██████████| 46/46 [00:00<00:00, 56.72it/s]
# 100%|██████████| 46/46 [00:00<00:00, 64.07it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.11it/s]
# 100%|██████████| 46/46 [00:00<00:00, 61.00it/s]
# Train set: Average loss: 0.0685, Average accuracy: 2.8318%,
#  	 Average f1_score: 0.0683, Average Area Under ROC: 0.4993
# 100%|██████████| 46/46 [00:00<00:00, 94.37it/s]
# [I 2022-09-27 16:47:47,520] Trial 1 finished with value: 0.07132026553153992 and parameters: {'n_layers': 4, 'n_units_l0': 98, 'dropout_l0': 0.3485147967968053, 'n_units_l1': 127, 'dropout_l1': 0.152069997281961, 'n_units_l2': 63, 'dropout_l2': 0.20602605607056607, 'n_units_l3': 252, 'dropout_l3': 0.15311634944425082, 'learning_rate': 0.04109166130002958, 'optimizer': 'SGD'}. Best is trial 1 with value: 0.07132026553153992.
# Test set: Average loss: 2.7506, Average accuracy: 0.0720%,
#  	  Average f1_score: 0.0713, Average Area Under ROC: 0.5033
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=127, bias=True)
#   (bn1): BatchNorm1d(127, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.12152950573363107, inplace=False)
#   (lin2): Linear(in_features=127, out_features=150, bias=True)
#   (bn2): BatchNorm1d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.3392374218663677, inplace=False)
#   (lin3): Linear(in_features=150, out_features=249, bias=True)
#   (bn3): BatchNorm1d(249, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.39520828380856765, inplace=False)
#   (lin4): Linear(in_features=249, out_features=83, bias=True)
#   (bn4): BatchNorm1d(83, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.10140337700341401, inplace=False)
#   (lin5): Linear(in_features=83, out_features=116, bias=True)
#   (bn5): BatchNorm1d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3313931438969484, inplace=False)
#   (lin6): Linear(in_features=116, out_features=245, bias=True)
#   (bn6): BatchNorm1d(245, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.26392179990700504, inplace=False)
#   (lin7): Linear(in_features=245, out_features=167, bias=True)
#   (bn7): BatchNorm1d(167, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.2586350364302378, inplace=False)
#   (fc_output): Linear(in_features=167, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 30.95it/s]
# 100%|██████████| 46/46 [00:01<00:00, 35.73it/s]
# 100%|██████████| 46/46 [00:01<00:00, 45.17it/s]
# 100%|██████████| 46/46 [00:01<00:00, 36.30it/s]
# [I 2022-09-27 16:47:52,767] Trial 2 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=46, bias=True)
#   (bn1): BatchNorm1d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3393224291532083, inplace=False)
#   (lin2): Linear(in_features=46, out_features=95, bias=True)
#   (bn2): BatchNorm1d(95, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.35009162675006367, inplace=False)
#   (lin3): Linear(in_features=95, out_features=54, bias=True)
#   (bn3): BatchNorm1d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.21724574080590997, inplace=False)
#   (fc_output): Linear(in_features=54, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 62.23it/s]
# 100%|██████████| 46/46 [00:00<00:00, 61.19it/s]
# 100%|██████████| 46/46 [00:00<00:00, 60.61it/s]
# 100%|██████████| 46/46 [00:00<00:00, 55.54it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.54it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.56it/s]
# 100%|██████████| 46/46 [00:00<00:00, 57.30it/s]
# Train set: Average loss: 0.0706, Average accuracy: 2.7672%,
#  	 Average f1_score: 0.0676, Average Area Under ROC: 0.4954
# 100%|██████████| 46/46 [00:00<00:00, 91.22it/s]
# [I 2022-09-27 16:47:59,075] Trial 3 finished with value: 0.060502827167510986 and parameters: {'n_layers': 3, 'n_units_l0': 46, 'dropout_l0': 0.3393224291532083, 'n_units_l1': 95, 'dropout_l1': 0.35009162675006367, 'n_units_l2': 54, 'dropout_l2': 0.21724574080590997, 'learning_rate': 0.0551840091491299, 'optimizer': 'RMSprop'}. Best is trial 1 with value: 0.07132026553153992.
# Test set: Average loss: 2.7168, Average accuracy: 0.0652%,
#  	  Average f1_score: 0.0605, Average Area Under ROC: 0.5100
#
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=113, bias=True)
#   (bn1): BatchNorm1d(113, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.16795075323896896, inplace=False)
#   (lin2): Linear(in_features=113, out_features=204, bias=True)
#   (bn2): BatchNorm1d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.48003152837553753, inplace=False)
#   (lin3): Linear(in_features=204, out_features=209, bias=True)
#   (bn3): BatchNorm1d(209, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.1643998359137398, inplace=False)
#   (lin4): Linear(in_features=209, out_features=147, bias=True)
#   (bn4): BatchNorm1d(147, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.43521839794059847, inplace=False)
#   (lin5): Linear(in_features=147, out_features=202, bias=True)
#   (bn5): BatchNorm1d(202, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel5): LeakyReLU(negative_slope=0.01)
#   (drop5): Dropout(p=0.3075440475394462, inplace=False)
#   (lin6): Linear(in_features=202, out_features=98, bias=True)
#   (bn6): BatchNorm1d(98, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel6): LeakyReLU(negative_slope=0.01)
#   (drop6): Dropout(p=0.12697843725722793, inplace=False)
#   (lin7): Linear(in_features=98, out_features=61, bias=True)
#   (bn7): BatchNorm1d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel7): LeakyReLU(negative_slope=0.01)
#   (drop7): Dropout(p=0.40960913479753724, inplace=False)
#   (lin8): Linear(in_features=61, out_features=127, bias=True)
#   (bn8): BatchNorm1d(127, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel8): LeakyReLU(negative_slope=0.01)
#   (drop8): Dropout(p=0.3602794358433127, inplace=False)
#   (fc_output): Linear(in_features=127, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 29.82it/s]
# 100%|██████████| 46/46 [00:01<00:00, 31.00it/s]
# 100%|██████████| 46/46 [00:01<00:00, 33.27it/s]
# 100%|██████████| 46/46 [00:01<00:00, 40.96it/s]
# [I 2022-09-27 16:48:04,824] Trial 4 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=250, bias=True)
#   (bn1): BatchNorm1d(250, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.4861178998596306, inplace=False)
#   (lin2): Linear(in_features=250, out_features=57, bias=True)
#   (bn2): BatchNorm1d(57, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.22662104720804246, inplace=False)
#   (lin3): Linear(in_features=57, out_features=117, bias=True)
#   (bn3): BatchNorm1d(117, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.1867418966206863, inplace=False)
#   (lin4): Linear(in_features=117, out_features=77, bias=True)
#   (bn4): BatchNorm1d(77, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.2807346835203226, inplace=False)
#   (fc_output): Linear(in_features=77, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:00<00:00, 46.59it/s]
# 100%|██████████| 46/46 [00:00<00:00, 49.84it/s]
# 100%|██████████| 46/46 [00:01<00:00, 41.29it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.10it/s]
# [I 2022-09-27 16:48:09,112] Trial 5 pruned.
# NetModel(
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (lin1): Linear(in_features=78, out_features=144, bias=True)
#   (bn1): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel1): LeakyReLU(negative_slope=0.01)
#   (drop1): Dropout(p=0.3414820241510189, inplace=False)
#   (lin2): Linear(in_features=144, out_features=80, bias=True)
#   (bn2): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel2): LeakyReLU(negative_slope=0.01)
#   (drop2): Dropout(p=0.4285439468250427, inplace=False)
#   (lin3): Linear(in_features=80, out_features=164, bias=True)
#   (bn3): BatchNorm1d(164, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel3): LeakyReLU(negative_slope=0.01)
#   (drop3): Dropout(p=0.3025046316029978, inplace=False)
#   (lin4): Linear(in_features=164, out_features=44, bias=True)
#   (bn4): BatchNorm1d(44, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrel4): LeakyReLU(negative_slope=0.01)
#   (drop4): Dropout(p=0.16349414893142025, inplace=False)
#   (fc_output): Linear(in_features=44, out_features=32, bias=True)
# )
# 100%|██████████| 46/46 [00:01<00:00, 43.21it/s]
# 100%|██████████| 46/46 [00:01<00:00, 41.33it/s]
# 100%|██████████| 46/46 [00:01<00:00, 43.29it/s]
# 100%|██████████| 46/46 [00:00<00:00, 46.46it/s]
# [I 2022-09-27 16:48:13,517] Trial 6 pruned.

# %%
trials_finished = study.get_trials()
print('number of trials finished: ', len(trials_finished),'\n')

print('number of the best trial: ',study.best_trial.number)

for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# number of trials finished:  7
#
# number of the best trial:  1
# n_layers: 9
# n_units_l0: 132
# dropout_l0: 0.3177073865653305
# n_units_l1: 155
# dropout_l1: 0.4369792022829979
# n_units_l2: 36
# dropout_l2: 0.2223535243560658
# n_units_l3: 114
# dropout_l3: 0.20518576324820215
# n_units_l4: 176
# dropout_l4: 0.1281504694783073
# n_units_l5: 124
# dropout_l5: 0.34017665690399823
# n_units_l6: 227
# dropout_l6: 0.22189160751583425
# n_units_l7: 112
# dropout_l7: 0.38864537534287646
# n_units_l8: 101
# dropout_l8: 0.30672992122504017
# learning_rate: 0.03547252206469744
# optimizer: Adam

# %% [markdown]
# ### Tuning Visualization

# %%
import plotly
optuna.visualization.plot_intermediate_values(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_slice(study)
